# %% [markdown]
# <a href="https://colab.research.google.com/github/priya170807/text_analysis/blob/master/datacleaning_flipkart_version7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import re
import sys
import pickle
import pandas as pd
import numpy as np
from collections import Counter

# %%
df = pd.read_csv("/content/drive/MyDrive/datasets/flipkart_com-ecommerce_sample.csv")

# %%
df.head()
# Out:
#                             uniq_id  ...                             product_specifications
# 0  c2d766ca982eca8304150849735ffef9  ...  {"product_specification"=>[{"key"=>"Number of ...
# 1  7f7036a6d550aaa89d34c77bd39a5e48  ...  {"product_specification"=>[{"key"=>"Installati...
# 2  f449ec65dcbc041b6ae5e6a32717d01b  ...  {"product_specification"=>[{"key"=>"Ideal For"...
# 3  0973b37acd0c664e3de26e97e5571454  ...  {"product_specification"=>[{"key"=>"Number of ...
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  ...  {"product_specification"=>[{"key"=>"Pet Type",...
#
# [5 rows x 15 columns]

# %%
useful_data = df[["product_name","product_category_tree", "description", "brand"]]

# %%
useful_data.head()
# Out:
#                             product_name  ...         brand
# 0    Alisha Solid Women's Cycling Shorts  ...        Alisha
# 1    FabHomeDecor Fabric Double Sofa Bed  ...  FabHomeDecor
# 2                             AW Bellies  ...            AW
# 3    Alisha Solid Women's Cycling Shorts  ...        Alisha
# 4  Sicons All Purpose Arnica Dog Shampoo  ...        Sicons
#
# [5 rows x 4 columns]

# %%
len(useful_data)
# Out:
# 20000

# %%
data = useful_data.copy()

# %% [markdown]
# Remove all the non-word characters and also the " ' " between the letters in the product_name.

# %%
# lets clean the product_name column
data["product_name"] = data["product_name"].str.replace(r'(?<=[a-zA-Z\d\s])\'(?=[a-zA-Z\d\s])', r"", regex=True)

# %%
data["product_name"] = data["product_name"].str.replace(r'[^a-zA-Z\d\s]', r"", regex=True)

# %%
data["product_name"] = data["product_name"].str.replace(r'Dr.', r'Dr',regex=True)

# %%
# randomly check the product_name column 
data["product_name"][12]
# Out:
# 'Sicons All Purpose Tea Tree Dog Shampoo'

# %%
data["product_name"][440]
# Out:
# 'Asian Gems  Jewels 5 Dhaatu Metal Alloy Zircon Ring'

# %%
data["product_name"][339]
# Out:
# 'Drssberry Black Synthetic  Clutch'

# %% [markdown]
# Clean the product_category_tree column.

# %%
# create new column "mainsnak" which is same as data["product_category_tree"]
data["mainsnak"] = data["product_category_tree"]

# %%
data["mainsnak"][0]
# Out:
# '["Clothing >> Women\'s Clothing >> Lingerie, Sleep & Swimwear >> Shorts >> Alisha Shorts >> Alisha Solid Women\'s Cycling Shorts"]'

# %%
# we can see a single quotes occuring in the mainsnak column
data["mainsnak"][57]
# Out:
# '["MASARA Solid Women\'s Straight Kurta"]'

# %%
# create a function to split the rows in data["product_category_tree"] and get the first string or the string at zeroth position.
def get_instance_of_entries(entry):
  entry_list = entry.split(">>")
  first_word = entry_list[0].rstrip()
  first_word = re.sub(r'[^a-zA-Z\d\s]', r'', first_word)
  first_word = re.sub(r'Dr.', r'Dr', first_word)
  # first_word = re.sub(r'[["]', r'', first_word)
  # first_word = re.sub(r'["]]', r'', first_word)
  return first_word

# %%
# apply the function get_instance_of_entries to mainsnak column and get the string in zeroth position. 
data["mainsnak"] = data["mainsnak"].map(lambda x : get_instance_of_entries(x))

# %%
data["mainsnak"][57]
# Out:
# 'MASARA Solid Womens Straight Kurta'

# %%
data["mainsnak"][65]
# Out:
# 'Libas Printed Womens Anarkali Kurta'

# %% [markdown]
# Remove all the non-word characters and also the " ' " between the letters in the column brand.

# %%
# lets clean the brand column
# replace the single quotes by empty space
data["brand"] = data["brand"].str.replace(r'(?<=[a-zA-Z\d\s])\'(?=[a-zA-Z\d\s])', r"", regex=True)

# %%
data["brand"] = data["brand"].str.replace(r'[^a-zA-Z\d\s]', r"", regex=True)

# %%
data["brand"] = data["brand"].str.replace(r'Dr.', r'Dr',regex=True)

# %%
data["brand"][5357]
# Out:
# 'Mi Dulce Anya'

# %%
data["brand"][19289]
# Out:
# 'Cynthias Fashion'

# %%
data["brand"][19120]
# Out:
# 'Layerr'

# %% [markdown]
# check the data["description"] column and start cleaning it

# %%
# creating a new column data["new_desc"] from data["description"]
data["new_desc"] = data["description"]

# %%
# removing the Rs. from the data since our end-token is the '.'
data["new_desc"] = data["new_desc"].str.replace(r'Rs.', '',regex=True)

# %%
data["new_desc"] = data["new_desc"].str.replace(r'Dr.', r'Dr',regex=True)

# %%
data["new_desc"][1]
# Out:
# "FabHomeDecor Fabric Double Sofa Bed (Finish Color - Leatherette Black Mechanism Type - Pull Out) Price:  22,646 • Fine deep seating experience • Save Space with the all new click clack Sofa Bed • Easy to fold and vice versa with simple click clack mechanism • Chrome legs with mango wood frame for long term durability • Double cushioned Sofa Bed to provide you with extra softness to make a fine seating experience • A double bed that can easily sleep two,Specifications of FabHomeDecor Fabric Double Sofa Bed (Finish Color - Leatherette Black Mechanism Type - Pull Out) Installation & Demo Installation & Demo Details Installation and demo for this product is done free of cost as part of this purchase. Our service partner will visit your location within 72 business hours from the delivery of the product. In The Box 1 Sofa Bed General Brand FabHomeDecor Mattress Included No Delivery Condition Knock Down Storage Included No Mechanism Type Pull Out Type Sofa Bed Style Contemporary & Modern Filling Material Microfiber Seating Capacity 3 Seater Upholstery Type NA Upholstery Included No Bed Size Double Shape Square Suitable For Living Room Model Number FHD112 Care Instructions Avoid outdoor use and exposure to water or prolonged moisture, Avoid exposure to direct heat or sunlight as this can cause the sofa colour to fade, Keep sharp objects away from your sofa, A little tear on the fabric cover may be hard to repair, Vacuum your sofas periodically with a soft bristled bru...View More Avoid outdoor use and exposure to water or prolonged moisture, Avoid exposure to direct heat or sunlight as this can cause the sofa colour to fade, Keep sharp objects away from your sofa, A little tear on the fabric cover may be hard to repair, Vacuum your sofas periodically with a soft bristled brush attachment or lightly brush them to keep general dirt and dust off the sofa and prevent any embedding between the fibres, Try to avoid food and drink spillage of any kind, If spills occur, do not leave unattended, In case of a stain, a water-free fabric cleaner can be used, However, avoid applying the cleaner directly on the stain as this can cause damage to the fabric and fade colour, Pour the cleaner onto a clean cloth and test its effect on a hidden area of the sofa before cleaning the stain with the cloth, A professional scotchguard treatment is one of the easiest and most effective options to protect against spills or stains and keep pet hair at bay, Getting your sofa professionally cleaned once every 6-8 months will not only take care of the nooks and corners
W).\nIn Hindi, '9' means 'Nav' and '5' means 'Punch'. Gem is called 'Ratna', whereas any 'Metal or Mineral or Element' is referred as 'Dhaatu'.\nRegarding 9 Gemstones. 'Nav Ratnas' means an 'Astro Planetary' communicating team of 9 Precious and Semi Precious Gemstones those are believed to reach and connect out to 9 Planets residing, revolving in our galaxy. \nIn the Birth Horoscope of an individual, if any planet is weak or some other planets are not sitting in the right degree/position or house or are opposing or suppressing some other planets than :-\nRUBY (MANIK) is considered to connect, enhance and empower Planet Sun (Surya) . \nBLUE SAPPHIRE (NEELAM) is considered to connect, enhance and empower Planet Saturn (Shani). \nYELLOW SAPPHIRE (PUKHRAJ) is considered to connect, enhance and empower Planet Jupiter (Guru).\nCORAL (MOONGA ) is considered to connect, enhance and empower Planet Mars (Moonga).\nEMERALD (PANNA) is considered to connect, enhance and empower Planet Mercury (Budh).\nPEARL (MOTI) is considered to con ...

# %%
# this is a regex creating a space after : or , or ; or ( or - when the immediate character that follows is not space.
data["new_desc"] = data["new_desc"].str.replace(r'(?<=[:;,(-])(?=[^\s])', r' ',regex=True)

# %%
# this is a regex creates a space for every word character that is followed by any of the non-word charcter defined in the positive lookahead group ([!):;,-])
data["new_desc"] = data["new_desc"].str.replace(r'(?<=[\w])([!):;,-])', r' \1',regex=True)

# %%
# this is a regex creates a space for every word character or non-word character that is followed by one or more period(non-word charcter) 
# defined in the positive lookahead group (\.+)
data["new_desc"] = data["new_desc"].str.replace(r'(?<=[\w\W])([\.+])', r' ',regex=True)

# %%
# this sis a regex that creates a single space in place of multiple spaces
data["new_desc"] = data["new_desc"].str.replace(r'\s{2,}', r' ',regex=True)

# %%
# this is a regex creates a space for every word character or non-word character that is followed by one or more newline (non-word charcter) 
# defined in the positive lookahead group (\n+)
data["new_desc"] = data["new_desc"].str.replace(r'(?<=[\w\W])([\n+])', r' ',regex=True)

# %%
# the regex for replacing single commas by no space charcater
data["new_desc"] = data["new_desc"].str.replace(r',', r'', regex=True)

# %%
# According to the text since the colon and the semicolon characters formed a meaningful sentence end, these characters are replaced by period.
# This is a regex to replace the colon(:) and the semicolon(;) by the period(.)
data["new_desc"] = data["new_desc"].str.replace(r'[:;]', r'.', regex=True)

# %%
data["new_desc"][5357]
# Out:
# "Specifications of Mi Dulce An'ya Solid Single Breasted Formal Boy's Blazer General Details Ideal For Boy's Occasion Formal Pattern Solid Blazer Details Type Single Breasted Fabric Organic Cotton Sleeve Full Sleeve Closure Button Pockets 2 Front Slip Pockets Vents Vent at back Lining Cotton Lining Number of Contents in Sales Package Pack of 1 Fabric Care Gentle Wash With Similar Colors Additional Details Style Code SS15 - IB - WC001A In the Box Blazer"

# %%
# regex to remove the single quotes between the word characters in a given text
data["new_desc"] =  data["new_desc"].str.replace(r'(?<=[a-zA-Z\d\s])\'(?=[a-zA-Z\d\s])', r"", regex=True)

# %%
# check few examples after cleaning the data.
data["new_desc"][93]
# Out:
# %%
def make_list(entry):
  temp_list=[]
  for string in entry:
    string_list = [item for item in string.split(" ") if not item == ""]
    temp_list.append(string_list)
  return temp_list

# %%
# create a function that splits the data in each row of the data["new_desc"] series by (" ").
data["new_desc"] = data["new_desc"].map(lambda x : make_list(x))

# %%
def append_period(entry):
  period = "."
  for lt in entry:
    lt.append(period)
  return entry

# %%
# create a function that appends each list in each row of the data["new_desc"] series by (.), which shows the end token for each sentence.
data["new_desc"] = data["new_desc"].map(lambda x : append_period(x))

# %%
# data["new_desc"][5357]

# %%
# check the data after transformations.
data.head()
# Out:
#                             product_name  ...                                           new_desc
# 0     Alisha Solid Womens Cycling Shorts  ...  [[Key, Features, of, Alisha, Solid, Womens, Cy...
# 1    FabHomeDecor Fabric Double Sofa Bed  ...  [[FabHomeDecor, Fabric, Double, Sofa, Bed, (, ...
# 2                             AW Bellies  ...  [[Key, Features, of, AW, Bellies, Sandals, Wed...
# 3     Alisha Solid Womens Cycling Shorts  ...  [[Key, Features, of, Alisha, Solid, Womens, Cy...
# 4  Sicons All Purpose Arnica Dog Shampoo  ...  [[Specifications, of, Sicons, All, Purpose, Ar...
#
# [5 rows x 6 columns]

# %%
# create new dataframe with useful columns.
new_df = data[["product_name", "mainsnak", "brand", "new_desc"]]

# %%
new_df.head()
# Out:
#                             product_name  ...                                           new_desc
# 0     Alisha Solid Womens Cycling Shorts  ...  [[Key, Features, of, Alisha, Solid, Womens, Cy...
# 1    FabHomeDecor Fabric Double Sofa Bed  ...  [[FabHomeDecor, Fabric, Double, Sofa, Bed, (, ...
# 2                             AW Bellies  ...  [[Key, Features, of, AW, Bellies, Sandals, Wed...
# 3     Alisha Solid Womens Cycling Shorts  ...  [[Key, Features, of, Alisha, Solid, Womens, Cy...
# 4  Sicons All Purpose Arnica Dog Shampoo  ...  [[Specifications, of, Sicons, All, Purpose, Ar...
#
# [5 rows x 4 columns]

# %%
# we observe that each row in the column "new_desc" is a list of list and each inner list is ended by a "." entry
# new_df["new_desc"][0]

# %%
new_df["new_desc"][5357]
# Out:
# [['Specifications',
#   'of',
#   'Mi',
#   'Dulce',
#   'Anya',
#   'Solid',
#   'Single',
#   'Breasted',
#   'Formal',
#   'Boys',
#   'Blazer',
#   'General',
#   'Details',
#   'Ideal',
#   'For',
#   'Boys',
#   'Occasion',
#   'Formal',
#   'Pattern',
#   'Solid',
#   'Blazer',
#   'Details',
#   'Type',
#   'Single',
#   'Breasted',
#   'Fabric',
#   'Organic',
#   'Cotton',
#   'Sleeve',
#   'Full',
#   'Sleeve',
#   'Closure',
#   'Button',
#   'Pockets',
#   '2',
#   'Front',
#   'Slip',
#   'Pockets',
#   'Vents',
#   'Vent',
#   'at',
#   'back',
#   'Lining',
#   'Cotton',
#   'Lining',
#   'Number',
#   'of',
#   'Contents',
#   'in',
#   'Sales',
#   'Package',
#   'Pack',
#   'of',
#   '1',
#   'Fabric',
#   'Care',
#   'Gentle',
#   'Wash',
#   'With',
#   'Similar',
#   'Colors',
#   'Additional',
#   'Details',
#   'Style',
#   'Code',
#   'SS15',
#   '-',
#   'IB',
#   '-',
#   'WC001A',
#   'In',
#   'the',
#   'Box',
#   'Blazer',
#   '.']]

# %%
len(new_df)
# Out:
# 20000

# %%
# change the column names matching to the wikidataset column names.
new_df.columns = ['Name_ID', 'mainsnak', 'brand', 'TEXT']

# %%
new_df.head()
# Out:
#                                  Name_ID  ...                                               TEXT
# 0     Alisha Solid Womens Cycling Shorts  ...  [[Key, Features, of, Alisha, Solid, Womens, Cy...
# 1    FabHomeDecor Fabric Double Sofa Bed  ...  [[FabHomeDecor, Fabric, Double, Sofa, Bed, (, ...
# 2                             AW Bellies  ...  [[Key, Features, of, AW, Bellies, Sandals, Wed...
# 3     Alisha Solid Womens Cycling Shorts  ...  [[Key, Features, of, Alisha, Solid, Womens, Cy...
# 4  Sicons All Purpose Arnica Dog Shampoo  ...  [[Specifications, of, Sicons, All, Purpose, Ar...
#
# [5 rows x 4 columns]

# %%
new_df.isnull().sum()
# Out:
# Name_ID        0
# mainsnak       0
# brand       5864
# TEXT           0
# dtype: int64

# %%
new_df = new_df.fillna("unknown")

# %%
new_df.isnull().sum()
# Out:
# Name_ID     0
# mainsnak    0
# brand       0
# TEXT        0
# dtype: int64

# %%
new_df.head()
# Out:
#                                  Name_ID  ...                                               TEXT
# 0     Alisha Solid Womens Cycling Shorts  ...  [[Key, Features, of, Alisha, Solid, Womens, Cy...
# 1    FabHomeDecor Fabric Double Sofa Bed  ...  [[FabHomeDecor, Fabric, Double, Sofa, Bed, (, ...
# 2                             AW Bellies  ...  [[Key, Features, of, AW, Bellies, Sandals, Wed...
# 3     Alisha Solid Womens Cycling Shorts  ...  [[Key, Features, of, Alisha, Solid, Womens, Cy...
# 4  Sicons All Purpose Arnica Dog Shampoo  ...  [[Specifications, of, Sicons, All, Purpose, Ar...
#
# [5 rows x 4 columns]

# %% [markdown]
# create a function "add_back_nameID", which adds the nameID to the text column

# %%
# new_df.to_csv("/content/drive/MyDrive/test_data/flipkart_cleaned.csv", index=False)

# %%
# copy new_df in processed_df
processed_df = new_df.copy()

# %%
len(processed_df)
# Out:
# 20000

# %%
processed_df.head()
# Out:
#                                  Name_ID  ...                                               TEXT
# 0     Alisha Solid Womens Cycling Shorts  ...  [[Key, Features, of, Alisha, Solid, Womens, Cy...
# 1    FabHomeDecor Fabric Double Sofa Bed  ...  [[FabHomeDecor, Fabric, Double, Sofa, Bed, (, ...
# 2                             AW Bellies  ...  [[Key, Features, of, AW, Bellies, Sandals, Wed...
# 3     Alisha Solid Womens Cycling Shorts  ...  [[Key, Features, of, Alisha, Solid, Womens, Cy...
# 4  Sicons All Purpose Arnica Dog Shampoo  ...  [[Specifications, of, Sicons, All, Purpose, Ar...
#
# [5 rows x 4 columns]

# %%
def data_preparation(df):
  # word_dict = {}
  data_list = []
  for index, row in df.iterrows():
    #text = [item for entry in row['TEXT'] for item in entry if item!=""]
    word_dict = {"Name_ID": row["Name_ID"], "taxon rank": [{"mainsnak": "Product"}],
                "parent taxon": [{"mainsnak": row["brand"]}], "instance of": [{"mainsnak": row['mainsnak']}], 
                "TEXT": row['TEXT']}
    data_list.append(word_dict.copy())
  return data_list

# %%
data_list_processed = data_preparation(processed_df)

# %%
# create a file name called new_df.json and write the data.
import json
with open("/content/drive/MyDrive/datasets/processed.json", "w") as f:
  for item in data_list_processed:
    f.write(json.dumps(item))
    f.write("\n")

# %%
# create another copy of new_df and further process it to add Name_ID back to the TEXT column.
addback_df = new_df.copy()

# %%
addback_df.head()
# Out:
#                                  Name_ID  ...                                               TEXT
# 0     Alisha Solid Womens Cycling Shorts  ...  [[Key, Features, of, Alisha, Solid, Womens, Cy...
# 1    FabHomeDecor Fabric Double Sofa Bed  ...  [[FabHomeDecor, Fabric, Double, Sofa, Bed, (, ...
# 2                             AW Bellies  ...  [[Key, Features, of, AW, Bellies, Sandals, Wed...
# 3     Alisha Solid Womens Cycling Shorts  ...  [[Key, Features, of, Alisha, Solid, Womens, Cy...
# 4  Sicons All Purpose Arnica Dog Shampoo  ...  [[Specifications, of, Sicons, All, Purpose, Ar...
#
# [5 rows x 4 columns]

# %%
def add_back_nameID(df):
  
  product_df=df.copy()

  print(len(product_df))
  # new_list = []
  for index, row in product_df.iterrows():
    # print(row)
    first_list = row["TEXT"][0].copy()
    # print("This is first list in a row")
    print(first_list)
    # print(row["Name_ID"])
    name_list = row["Name_ID"].split()
    # print(name_list)
    join_token = name_list[0]
    name_length = len(name_list)
    # print("lenght of name_list={}".format(name_length))
    # print(join_token)
    if join_token in first_list:
      # print("hello")
      try:
        word_index = first_list.index(join_token)
        # print("word_index", word_index)
      except ValueError as e:
        print(e)
      else:
        # for i in range(word_index, name_length-1):
        del first_list[word_index:word_index+name_length]
        print("\n")
        # print(".......................")
        # print(first_list)
        first_list.insert(word_index, row["Name_ID"])
        print(first_list)
        print("\n")
        print(".......................")
        row["TEXT"][0] = first_list
        product_df.at[index, "TEXT"]=row["TEXT"]
        # new_list.append(first_list)
        # print(row["TEXT"])
  return product_df

# %%
product_df = add_back_nameID(addback_df)
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# ['Key', 'Features', 'of', 'American Club ExclusiveTrolleyBag4DT Expandable  Checkin Luggage  28', 'Luggage', '-', '28', 'Outer', 'Material', '-', 'Nylon/Teflon', 'Inner', 'Material', '-', 'Satin/Nylon', 'Compartment', '-', '2', 'Outside', '1', 'Inside', 'Shell', 'Type', '-', 'Soft', 'Top', 'Handle', 'Type', '-', 'Inbuilt', 'Lock', 'Type', '-', 'Combination', 'Lock', 'Water', 'Resistant', 'Number', 'Of', 'Wheels', '-', '4', 'Light', 'weight', 'Durable', 'Stylish', '&', 'Trendy', 'Look', '360', 'Degree', 'Rotation', 'High', 'Grade', 'Aluminium', 'Handle', 'Expandable', 'American', 'Club', 'ExclusiveTrolleyBag4DT', 'Expandable', 'Check', '-', 'in', 'Luggage', '-', '28', '(', 'Maroon', ')', 'Price', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'PRINT', 'SHAPES', 'monster', 'university', 'party', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', 'Glue', 'Free', 'Removal', '15', '6', 'inches', 'Laptop', 'skin', 'Easy', 'to', 'Apply', '&', 'Scratch', 'Resistant', 'Lamination', 'PRINT', 'SHAPES', 'monster', 'university', 'party', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', '(', 'Multicolor', ')', 'Price', '.']
#
#
# ['Key', 'Features', 'of', 'PRINT SHAPES monster university party Laptop Skin with Mouse pad Combo Set', 'Glue', 'Free', 'Removal', '15', '6', 'inches', 'Laptop', 'skin', 'Easy', 'to', 'Apply', '&', 'Scratch', 'Resistant', 'Lamination', 'PRINT', 'SHAPES', 'monster', 'university', 'party', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', '(', 'Multicolor', ')', 'Price', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'AdroitZ', 'Premium', 'Phone', 'Socket', 'Holder', 'For', 'Apple', 'iPhone', '6', 'Type', '.']
#
#
# ['Key', 'Features', 'of', 'AdroitZ Premium Phone Socket Holder For Apple iPhone 6', 'Type', '.']
#
#
# .......................
# ['SARK', 'Angle', 'Valve', 'with', 'Flange', 'Faucet', 'Set', 'Price', '.']
#
#
# ['SARK Angle Valve with Flange Faucet Set', 'Price', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Sitaram', 'Womens', 'Top', 'and', 'Skirt', 'Set', 'Material', 'net', 'embordery', 'work', 'top', 'straight', 'cut', 'georgette', 'top', 'with', 'viscose', 'dupatta', 'poly', 'cotton', 'salwar', 'Sitaram', 'Womens', 'Top', 'and', 'Skirt', 'Set', 'Price', '.']
#
#
# ['Key', 'Features', 'of', 'Sitaram Womens Top and Skirt Set', 'Material', 'net', 'embordery', 'work', 'top', 'straight', 'cut', 'georgette', 'top', 'with', 'viscose', 'dupatta', 'poly', 'cotton', 'salwar', 'Sitaram', 'Womens', 'Top', 'and', 'Skirt', 'Set', 'Price', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'AdroitZ', 'Premium', 'Phone', 'Socket', 'Holder', 'For', 'HTC', 'One', 'S', 'Type', '.']
#
#
# ['Key', 'Features', 'of', 'AdroitZ Premium Phone Socket Holder For HTC One S', 'Type', '.']
#
#
# .......................
# ['Specifications', 'of', 'Tokidoki', 'Unicornos', 'Series', '3', 'Figure', '(', 'Multicolor', ')', 'Important', 'Note', 'The', 'color', 'of', 'some', 'product', 'parts', 'may', 'vary', 'from', 'what', 'is', 'shown', 'in', 'the', 'image', 'General', 'Age', 'Group', '3', '-', '6', 'Years', 'Ideal', 'for', 'Boys', 'Girls', 'Type', 'Action', 'Figure', 'Accessories', 'Character', 'Action', 'Figures', '.']
#
#
# ['Specifications', 'of', 'Tokidoki Unicornos Series 3 Figure', '(', 'Multicolor', ')', 'Important', 'Note', 'The', 'color', 'of', 'some', 'product', 'parts', 'may', 'vary', 'from', 'what', 'is', 'shown', 'in', 'the', 'image', 'General', 'Age', 'Group', '3', '-', '6', 'Years', 'Ideal', 'for', 'Boys', 'Girls', 'Type', 'Action', 'Figure', 'Accessories', 'Character', 'Action', 'Figures', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Lajo', 'Womens', 'Salwar', 'and', 'Dupatta', 'Set', 'Fabric', '.']
#
#
# ['Key', 'Features', 'of', 'Lajo Womens Salwar and Dupatta Set', 'Fabric', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Discovery', 'Toys', 'MarbleworksÃ¢Â®', 'Marble', 'Run', 'Starter', 'Set', 'By', 'Type', '.']
#
#
# ['Key', 'Features', 'of', 'Discovery Toys Marbleworks Marble Run Starter Set By', 'Type', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'PRINT', 'SHAPES', 'The', 'Hunger', 'girl', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', 'Glue', 'Free', 'Removal', '15', '6', 'inches', 'Laptop', 'skin', 'Easy', 'to', 'Apply', '&', 'Scratch', 'Resistant', 'Lamination', 'PRINT', 'SHAPES', 'The', 'Hunger', 'girl', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', '(', 'Multicolor', ')', 'Price', '.']
#
#
# ['Key', 'Features', 'of', 'PRINT SHAPES The Hunger girl Laptop Skin with Mouse pad Combo Set', 'Glue', 'Free', 'Removal', '15', '6', 'inches', 'Laptop', 'skin', 'Easy', 'to', 'Apply', '&', 'Scratch', 'Resistant', 'Lamination', 'PRINT', 'SHAPES', 'The', 'Hunger', 'girl', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', '(', 'Multicolor', ')', 'Price', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Wishkey', 'Wishkey', 'Combat', 'Gun', 'with', 'flashing', 'lights', 'and', 'Sound', 'Type', '.']
#
#
# ['Key', 'Features', 'of', 'Wishkey Wishkey Combat Gun with flashing lights and Sound', 'Type', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Simrit', 'Womens', 'Nighty', 'Fabric', '.']
#
#
# ['Key', 'Features', 'of', 'Simrit Womens Nighty', 'Fabric', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Aroma', 'Comfort', 'Polyester', 'Green', 'Self', 'Design', 'Eyelet', 'Door', 'Curtain', 'Height', '.']
#
#
# ['Key', 'Features', 'of', 'Aroma Comfort Polyester Green Self Design Eyelet Door Curtain', 'Height', '.']
#
#
# .......................
# ['Specifications', 'of', 'Lajo', 'Womens', 'Salwar', 'and', 'Dupatta', 'Set', 'General', 'Details', 'Sleeve', 'Full', 'Sleeve', 'Fabric', 'Net', 'Type', 'Salwar', 'and', 'Dupatta', 'Set', 'Pattern', 'Embroidered', 'Ideal', 'For', 'Womens', 'In', 'the', 'Box', '1', '.']
#
#
# ['Specifications', 'of', 'Lajo Womens Salwar and Dupatta Set', 'General', 'Details', 'Sleeve', 'Full', 'Sleeve', 'Fabric', 'Net', 'Type', 'Salwar', 'and', 'Dupatta', 'Set', 'Pattern', 'Embroidered', 'Ideal', 'For', 'Womens', 'In', 'the', 'Box', '1', '.']
#
#
# .......................
# ['Lady', 'Diana', 'Collection', 'Lip', 'Balm', 'for', 'Dr', 'Lips', 'Straberry', '(', '50', 'ml', ')', 'Price', '.']
#
#
# ['Lady Diana Collection Lip Balm for Dr Lips Straberry', '(', '50', 'ml', ')', 'Price', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Lajo', 'Womens', 'Salwar', 'and', 'Dupatta', 'Set', 'Fabric', '.']
#
#
# ['Key', 'Features', 'of', 'Lajo Womens Salwar and Dupatta Set', 'Fabric', '.']
#
#
# .......................
# ['Specifications', 'of', 'Lovely', 'Plastic', 'Desk', 'Chair', '(', 'Finish', 'Color', '-', 'Multicolor', ')', 'In', 'The', 'Box', '1', 'Kids', 'Table', '1', 'Kids', 'Chair', 'General', 'Foldable', 'Yes', 'Brand', 'Lovely', 'Delivery', 'Condition', 'DIY(', 'Do', '-', 'It', '-', 'Yourself', ')', 'Type', 'Desk', 'Chair', 'Style', 'Contemporary', '&', 'Modern', 'Seating', 'Capacity', '1', 'Seater', 'Upholstery', 'Type', 'NA', 'Upholstery', 'Included', 'No', 'Suitable', 'For', 'Outdoor', '&', 'Cafeteria', 'Model', 'Number', 'Portable', 'Table', 'Chair', 'G01', 'Armrest', 'Included', 'No', 'Finish', 'Type', 'Glossy', 'Care', 'Instructions', 'Clean', 'with', 'Soft', 'Cloth', 'Important', 'Note', 'The', 'color', 'of', 'some', 'product', 'parts', 'may', 'vary', 'from', 'what', 'is', 'shown', 'in', 'the', 'image', 'Dimensions', 'Weight', '1', 'kg', 'Height', '500', 'mm', 'Width', '420', 'mm', 'Depth', '400', 'mm', 'Warranty', 'Covered', 'in', 'Warranty', 'Manufacturing', 'Defects', 'only', 'Warranty', 'Summary', 'No', 'Warranaty', 'Available', 'Service', 'Type', 'No', 'Service', 'Available', 'Not', 'Covered', 'in', 'Warranty', 'Warranty', 'does', 'not', 'cover', 'any', 'external', 'damage', 'caused', 'to', 'the', 'product', 'due', 'to',
#
#
# ['Specifications', 'of', 'Auto Power Gold Butyl Auto Tube 3 Wheeler For EBike', '-', 'Bike', 'General', 'Type', '3', 'Wheeler', 'Tube', 'Features', 'Tube', 'Material', 'Rubber', 'Tube', 'Size', '16*300', 'Tyre', 'Features', 'Compatibility', 'E', '-', 'Bike', 'In', 'the', 'Box', 'Sales', 'Package', '1', 'Tyre', 'Tube', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Cynthias', 'Fashion', 'Womens', 'Girls', 'Kurta', 'Pyjama', '&', 'Dupatta', 'Set', 'Fabric', '.']
#
#
# ['Key', 'Features', 'of', 'Cynthias Fashion Womens Girls Kurta Pyjama  Dupatta Set', 'Set', 'Fabric', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'PRINT', 'SHAPES', 'Deep', 'ambition', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', 'Glue', 'Free', 'Removal', '15', '6', 'inches', 'Laptop', 'skin', 'Easy', 'to', 'Apply', '&', 'Scratch', 'Resistant', 'Lamination', 'PRINT', 'SHAPES', 'Deep', 'ambition', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', '(', 'Multicolor', ')', 'Price', '.']
#
#
# ['Key', 'Features', 'of', 'PRINT SHAPES Deep ambition Laptop Skin with Mouse pad Combo Set', 'Glue', 'Free', 'Removal', '15', '6', 'inches', 'Laptop', 'skin', 'Easy', 'to', 'Apply', '&', 'Scratch', 'Resistant', 'Lamination', 'PRINT', 'SHAPES', 'Deep', 'ambition', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', '(', 'Multicolor', ')', 'Price', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'PRINT', 'SHAPES', 'mind', 'haker', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', 'Glue', 'Free', 'Removal', '15', '6', 'inches', 'Laptop', 'skin', 'Easy', 'to', 'Apply', '&', 'Scratch', 'Resistant', 'Lamination', 'PRINT', 'SHAPES', 'mind', 'haker', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', '(', 'Multicolor', ')', 'Price', '.']
#
#
# ['Key', 'Features', 'of', 'PRINT SHAPES mind haker Laptop Skin with Mouse pad Combo Set', 'Glue', 'Free', 'Removal', '15', '6', 'inches', 'Laptop', 'skin', 'Easy', 'to', 'Apply', '&', 'Scratch', 'Resistant', 'Lamination', 'PRINT', 'SHAPES', 'mind', 'haker', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', '(', 'Multicolor', ')', 'Price', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'AdroitZ', 'Premium', 'Phone', 'Socket', 'Holder', 'For', 'Palm', 'Pre', 'Type', '.']
#
#
# ['Key', 'Features', 'of', 'AdroitZ Premium Phone Socket Holder For Palm Pre', 'Type', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Simrit', 'Womens', 'Nighty', 'Fabric', '.']
#
#
# ['Key', 'Features', 'of', 'Simrit Womens Nighty', 'Fabric', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'PRINT', 'SHAPES', 'minion', 'superhero', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', 'Glue', 'Free', 'Removal', '15', '6', 'inches', 'Laptop', 'skin', 'Easy', 'to', 'Apply', '&', 'Scratch', 'Resistant', 'Lamination', 'PRINT', 'SHAPES', 'minion', 'superhero', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', '(', 'Multicolor', ')', 'Price', '.']
#
#
# ['Key', 'Features', 'of', 'PRINT SHAPES minion superhero Laptop Skin with Mouse pad Combo Set', 'Glue', 'Free', 'Removal', '15', '6', 'inches', 'Laptop', 'skin', 'Easy', 'to', 'Apply', '&', 'Scratch', 'Resistant', 'Lamination', 'PRINT', 'SHAPES', 'minion', 'superhero', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', '(', 'Multicolor', ')', 'Price', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'AdroitZ', 'Premium', 'Phone', 'Socket', 'Holder', 'For', 'LG', 'CT810', 'Incite', 'Type', '.']
#
#
# ['Key', 'Features', 'of', 'AdroitZ Premium Phone Socket Holder For LG CT810 Incite', 'Type', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Aroma', 'Comfort', 'Polyester', 'Brown', 'Self', 'Design', 'Eyelet', 'Long', 'Door', 'Curtain', 'Height', '.']
#
#
# ['Key', 'Features', 'of', 'Aroma Comfort Polyester Brown Self Design Eyelet Long Door Curtain', 'Height', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Blizzard', 'Entertainment', 'World', 'of', 'Warcraft', 'Illidan', 'Funko', 'POP', '!', 'Vinyl', 'Figure', 'Type', '.']
#
#
# ['Key', 'Features', 'of', 'Blizzard Entertainment World of Warcraft Illidan Funko POP Vinyl Figure', 'Figure', 'Type', '.']
#
#
# .......................
# ['SARK', '2', 'in', '1', 'Bib', 'Cock', 'with', 'Flange', 'Faucet', 'Set', 'Price', '.']
#
#
# ['SARK 2 in 1 Bib Cock with Flange Faucet Set', 'Price', '.']
#
#
# .......................
# ['Specifications', 'of', 'MUA', 'MAKEUP', 'ACADEMY', 'SWEET', 'SHEEN', 'DUSKY', 'ROSE', '(', '2', '8', 'g', ')', 'Lip', 'Balm', 'Traits', 'Flavor', 'DUSKY', 'ROSE', 'General', 'Traits', 'Organic', 'Type', 'NATURAL', 'Quantity', '2', '8', 'g', 'Shade', 'MAROON', 'Ideal', 'For', 'Women', 'In', 'the', 'Box', '1', 'LIP', 'BALM', '.']
#
#
# ['Specifications', 'of', 'MUA MAKEUP ACADEMY SWEET SHEEN DUSKY ROSE', '(', '2', '8', 'g', ')', 'Lip', 'Balm', 'Traits', 'Flavor', 'DUSKY', 'ROSE', 'General', 'Traits', 'Organic', 'Type', 'NATURAL', 'Quantity', '2', '8', 'g', 'Shade', 'MAROON', 'Ideal', 'For', 'Women', 'In', 'the', 'Box', '1', 'LIP', 'BALM', '.']
#
#
# .......................
# ['Specifications', 'of', 'Lajo', 'Womens', 'Salwar', 'and', 'Dupatta', 'Set', 'General', 'Details', 'Sleeve', 'Full', 'Sleeve', 'Fabric', 'Georgette', 'Type', 'Salwar', 'and', 'Dupatta', 'Set', 'Pattern', 'Embroidered', 'Ideal', 'For', 'Womens', 'In', 'the', 'Box', '1', '.']
#
#
# ['Specifications', 'of', 'Lajo Womens Salwar and Dupatta Set', 'General', 'Details', 'Sleeve', 'Full', 'Sleeve', 'Fabric', 'Georgette', 'Type', 'Salwar', 'and', 'Dupatta', 'Set', 'Pattern', 'Embroidered', 'Ideal', 'For', 'Womens', 'In', 'the', 'Box', '1', '.']
#
#
# .......................
# ['Specifications', 'of', 'SafeAnBTouch', 'IC5001', 'Cold', 'Pack', '(', 'White', 'Multicolor', ')', 'General', 'Re', '-', 'usable', 'Yes', 'Purpose', 'Warming', 'Swelling', 'Area', 'of', 'Use', 'Forehead', 'Hands', 'Legs', 'Abdomen', 'Shoulders', 'In', 'the', 'Box', 'Number', 'of', 'Contents', 'in', 'Sales', 'Package', 'Pack', 'of', '1', 'Sales', 'Package', '1', 'Cold', 'Pack', '.']
#
#
# ['Specifications', 'of', 'SafeAnBTouch IC5001 Cold Pack', '(', 'White', 'Multicolor', ')', 'General', 'Re', '-', 'usable', 'Yes', 'Purpose', 'Warming', 'Swelling', 'Area', 'of', 'Use', 'Forehead', 'Hands', 'Legs', 'Abdomen', 'Shoulders', 'In', 'the', 'Box', 'Number', 'of', 'Contents', 'in', 'Sales', 'Package', 'Pack', 'of', '1', 'Sales', 'Package', '1', 'Cold', 'Pack', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Aroma', 'Comfort', 'Polyester', 'Multi', 'Color', 'Striped', 'Rod', 'pocket', 'Door', 'Curtain', 'Height', '.']
#
#
# ['Key', 'Features', 'of', 'Aroma Comfort Polyester Multi Color Striped Rod pocket Door Curtain', 'Height', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Shreeka', 'Womens', 'Patiala', 'and', 'Dupatta', 'Set', 'Fabric', '.']
#
#
# ['Key', 'Features', 'of', 'Shreeka Womens Patiala and Dupatta Set', 'Fabric', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Simrit', 'Womens', 'Nighty', 'Fabric', '.']
#
#
# ['Key', 'Features', 'of', 'Simrit Womens Nighty', 'Fabric', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'AdroitZ', 'Premium', 'Phone', 'Socket', 'Holder', 'For', 'Sony', 'Xperia', 'SP', 'Type', '.']
#
#
# ['Key', 'Features', 'of', 'AdroitZ Premium Phone Socket Holder For Sony Xperia SP', 'Type', '.']
#
#
# .......................
# ['Key', 'Features', 'of', '69th', 'Avenue', '69SS0003', '-', 'B6', 'Polyester', 'Steel', 'Sliding', 'Pin', 'Shirt', 'Stud', 'Shape', '.']
#
#
# ['Key', 'Features', 'of', '69th Avenue 69SS0003B6 Polyester Steel Sliding Pin Shirt Stud', 'Shirt', 'Stud', 'Shape', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'PRINT', 'SHAPES', 'Graphic', 'Dancer', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', 'Glue', 'Free', 'Removal', '15', '6', 'inches', 'Laptop', 'skin', 'Easy', 'to', 'Apply', '&', 'Scratch', 'Resistant', 'Lamination', 'PRINT', 'SHAPES', 'Graphic', 'Dancer', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', '(', 'Multicolor', ')', 'Price', '.']
#
#
# ['Key', 'Features', 'of', 'PRINT SHAPES Graphic Dancer Laptop Skin with Mouse pad Combo Set', 'Glue', 'Free', 'Removal', '15', '6', 'inches', 'Laptop', 'skin', 'Easy', 'to', 'Apply', '&', 'Scratch', 'Resistant', 'Lamination', 'PRINT', 'SHAPES', 'Graphic', 'Dancer', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', '(', 'Multicolor', ')', 'Price', '.']
#
#
# .......................
# ['Specifications', 'of', 'The', 'Loyal', 'Subjects', 'Diy', 'Optimus', 'Prime', '(', 'White', ')', 'Important', 'Note', 'The', 'color', 'of', 'some', 'product', 'parts', 'may', 'vary', 'from', 'what', 'is', 'shown', 'in', 'the', 'image', 'General', 'Character', 'Diy', 'optimus', 'prime', '.']
#
#
# ['Specifications', 'of', 'The Loyal Subjects Diy Optimus Prime', '(', 'White', ')', 'Important', 'Note', 'The', 'color', 'of', 'some', 'product', 'parts', 'may', 'vary', 'from', 'what', 'is', 'shown', 'in', 'the', 'image', 'General', 'Character', 'Diy', 'optimus', 'prime', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Lajo', 'Womens', 'Salwar', 'and', 'Dupatta', 'Set', 'Fabric', '.']
#
#
# ['Key', 'Features', 'of', 'Lajo Womens Salwar and Dupatta Set', 'Fabric', '.']
#
#
# .......................
# ['Specifications', 'of', 'PRINT', 'SHAPES', 'Caution', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', '(', 'Multicolor', ')', 'General', 'Brand', 'PRINT', 'SHAPES', 'Model', 'Name', 'Caution', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Suitable_for', 'All', 'types', 'of', 'Laptop', 'Color', 'Multicolor', 'Warranty', 'Warranty', 'Summary', 'No', 'Warranty', 'In', 'the', 'Box', 'Number', 'of', 'Contents', 'in', 'Sales', 'Package', 'Pack', 'of', '2', '.']
#
#
# ['Specifications', 'of', 'PRINT SHAPES Caution Laptop Skin with Mouse pad Combo Set', '(', 'Multicolor', ')', 'General', 'Brand', 'PRINT', 'SHAPES', 'Model', 'Name', 'Caution', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Suitable_for', 'All', 'types', 'of', 'Laptop', 'Color', 'Multicolor', 'Warranty', 'Warranty', 'Summary', 'No', 'Warranty', 'In', 'the', 'Box', 'Number', 'of', 'Contents', 'in', 'Sales', 'Package', 'Pack', 'of', '2', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Lajo', 'Womens', 'Salwar', 'and', 'Dupatta', 'Set', 'Fabric', '.']
#
#
# ['Key', 'Features', 'of', 'Lajo Womens Salwar and Dupatta Set', 'Fabric', '.']
#
#
# .......................
# ['Specifications', 'of', 'Lajo', 'Womens', 'Salwar', 'and', 'Dupatta', 'Set', 'General', 'Details', 'Sleeve', 'Full', 'Sleeve', 'Fabric', 'Crape', 'Type', 'Salwar', 'and', 'Dupatta', 'Set', 'Pattern', 'Embroidered', 'Ideal', 'For', 'Womens', 'In', 'the', 'Box', '2', 'Ethnic', 'Set', '.']
#
#
# ['Specifications', 'of', 'Lajo Womens Salwar and Dupatta Set', 'General', 'Details', 'Sleeve', 'Full', 'Sleeve', 'Fabric', 'Crape', 'Type', 'Salwar', 'and', 'Dupatta', 'Set', 'Pattern', 'Embroidered', 'Ideal', 'For', 'Womens', 'In', 'the', 'Box', '2', 'Ethnic', 'Set', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Aroma', 'Comfort', 'Polyester', 'Brown', 'Printed', 'Eyelet', 'Window', 'Curtain', 'Height', '.']
#
#
# ['Key', 'Features', 'of', 'Aroma Comfort Polyester Brown Printed Eyelet Window Curtain', 'Height', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Whirlpool', 'Affresh', 'Stainless', 'Steel', 'Cleaning', 'Wipes', 'Kitchen', 'Cleaner', 'THE', '#1', 'SELLING', 'MAJOR', 'APPLIANCE', 'MANUFACTURER', 'IN', 'WORLD', 'RECOMENDS', 'THIS', 'PRODUCT', 'Easily', 'cleans', 'fingerprints', 'smudges', 'and', 'residue', 'for', 'a', 'streak', '-', 'free', 'polished', 'shine', 'Helps', 'keep', 'your', 'appliances', 'performing', 'and', 'appearing', 'like', 'new', 'Whirlpool', 'Affresh', 'Stainless', 'Steel', 'Cleaning', 'Wipes', 'Kitchen', 'Cleaner', '(', '200', ')', 'Price', '.']
#
#
# ['Key', 'Features', 'of', 'Whirlpool Affresh Stainless Steel Cleaning Wipes Kitchen Cleaner', 'THE', '#1', 'SELLING', 'MAJOR', 'APPLIANCE', 'MANUFACTURER', 'IN', 'WORLD', 'RECOMENDS', 'THIS', 'PRODUCT', 'Easily', 'cleans', 'fingerprints', 'smudges', 'and', 'residue', 'for', 'a', 'streak', '-', 'free', 'polished', 'shine', 'Helps', 'keep', 'your', 'appliances', 'performing', 'and', 'appearing', 'like', 'new', 'Whirlpool', 'Affresh', 'Stainless', 'Steel', 'Cleaning', 'Wipes', 'Kitchen', 'Cleaner', '(', '200', ')', 'Price', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Aroma', 'Comfort', 'Polyester', 'Purple', 'Printed', 'Eyelet', 'Long', 'Door', 'Curtain', 'Height', '.']
#
#
# ['Key', 'Features', 'of', 'Aroma Comfort Polyester Purple Printed Eyelet Long Door Curtain', 'Height', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Sitaram', 'Womens', 'Top', 'and', 'Skirt', 'Set', 'Material', '-', 'Georgette', 'Color', '-', 'black', 'Full', 'sleeves', 'zari', 'embroidery', '2', '25', 'meter', 'dupatta', 'Sitaram', 'Womens', 'Top', 'and', 'Skirt', 'Set', 'Price', '.']
#
#
# ['Key', 'Features', 'of', 'Sitaram Womens Top and Skirt Set', 'Material', '-', 'Georgette', 'Color', '-', 'black', 'Full', 'sleeves', 'zari', 'embroidery', '2', '25', 'meter', 'dupatta', 'Sitaram', 'Womens', 'Top', 'and', 'Skirt', 'Set', 'Price', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Hunter', 'Electric', 'Insect', 'Killer', 'Safe', 'power', 'input', 'harmful', 'to', 'insect', 'only', 'not', 'to', 'human', 'being', 'and', 'pets', 'Insects', 'are', 'killed', 'instantly', 'on', 'the', 'spot', 'by', 'electric', 'shock', 'Environmentally', '100%', 'safe', 'Convenient', 'to', 'handle', 'for', 'both', 'indoor', 'and', 'outdoor', 'purposes', 'No', 'smell', 'no', 'environmental', 'pollution', 'No', 'side', 'effects', 'and', 'allergies', 'from', 'chemical', 'like', 'Althrine', 'The', 'net', 'delivers', 'a', 'high', 'voltage', 'with', 'low', 'current', 'which', 'is', 'deadly', 'for', 'any', 'insect', 'Specifications', 'of', 'Hunter', 'Electric', 'Insect', 'Killer', '(', 'Bat', ')', 'Convenience', 'Features', 'Cordless', 'Yes', 'LED', 'Light', 'No', 'Automatic', 'Power', 'On/Off', 'No', 'Wrist', 'Strap', 'No', 'General', 'Brand', 'Hunter', 'Suitable', 'For', 'Indoor', 'Outdoor', 'Number', 'of', 'Net', 'Layers', '3', 'Model', 'Number', 'Brand', 'Mosquito', 'Swatter', 'Zapper', 'Racket', '100%', 'Environment', 'Friendly', 'Shock', 'Proof', 'Safe', 'for', 'Human', 'Pets', 'Type', 'Bat', 'Chemical', 'Free', 'Yes', 'Material', 'Plastic', 'Color', 'Yellow', 'Warranty', 'Covered', 'in', 'Warranty', 'Warranty', 'of', 'the', 'product', 'is', 'limited', 'to', 'manufacturing', 'defects', 'only', 'Warranty', 'Summary', '6', 'months', 'manufacturer', 'warranty', 'Not', 'Covered', 'in', 'Warranty', 'Warranty', 'does', 'not', 'cover', 'any', 'external', 'accessories', '(', 'such', 'as', 'battery', 'cable', 'carrying', 'bag', ')', 'damage', 'caused', 'to', 'the', 'product', 'due', 'to', 'improper', 'installation', 'by', 'customer', 'normal', 'wear', 'and', 'tear', 'to', 'magnetic', 'heads', 'audio', 'video', 'laser', 'pick', '-', 'ups', 'and', 'TV', 'picture', 'tubes', 'pane', 'Power', 'Features', 'Rechargeable', 'Yes', 'Power', 'Source', 'Rechargeable', 'Battery', 'In', 'the', 'Box', '1', 'Mosquito', 'Killer', 'Bat', '.']
#
#
# ['Key', 'Features', 'of', 'Hunter Electric Insect Killer', 'Safe', 'power', 'input', 'harmful', 'to', 'insect', 'only', 'not', 'to', 'human', 'being', 'and', 'pets', 'Insects', 'are', 'killed', 'instantly', 'on', 'the', 'spot', 'by', 'electric', 'shock', 'Environmentally', '100%', 'safe', 'Convenient', 'to', 'handle', 'for', 'both', 'indoor', 'and', 'outdoor', 'purposes', 'No', 'smell', 'no', 'environmental', 'pollution', 'No', 'side', 'effects', 'and', 'allergies', 'from', 'chemical', 'like', 'Althrine', 'The', 'net', 'delivers', 'a', 'high', 'voltage', 'with', 'low', 'current', 'which', 'is', 'deadly', 'for', 'any', 'insect', 'Specifications', 'of', 'Hunter', 'Electric', 'Insect', 'Killer', '(', 'Bat', ')', 'Convenience', 'Features', 'Cordless', 'Yes', 'LED', 'Light', 'No', 'Automatic', 'Power', 'On/Off', 'No', 'Wrist', 'Strap', 'No', 'General', 'Brand', 'Hunter', 'Suitable', 'For', 'Indoor', 'Outdoor', 'Number', 'of', 'Net', 'Layers', '3', 'Model', 'Number', 'Brand', 'Mosquito', 'Swatter', 'Zapper', 'Racket', '100%', 'Environment', 'Friendly', 'Shock', 'Proof', 'Safe', 'for', 'Human', 'Pets', 'Type', 'Bat', 'Chemical', 'Free', 'Yes', 'Material', 'Plastic', 'Color', 'Yellow', 'Warranty', 'Covered', 'in', 'Warranty', 'Warranty', 'of', 'the', 'product', 'is', 'limited', 'to', 'manufacturing', 'defects', 'only', 'Warranty', 'Summary', '6', 'months', 'manufacturer', 'warranty', 'Not', 'Covered', 'in', 'Warranty', 'Warranty', 'does', 'not', 'cover', 'any', 'external', 'accessories', '(', 'such', 'as', 'battery', 'cable', 'carrying', 'bag', ')', 'damage', 'caused', 'to', 'the', 'product', 'due', 'to', 'improper', 'installation', 'by', 'customer', 'normal', 'wear', 'and', 'tear', 'to', 'magnetic', 'heads', 'audio', 'video', 'laser', 'pick', '-', 'ups', 'and', 'TV', 'picture', 'tubes', 'pane', 'Power', 'Features', 'Rechargeable', 'Yes', 'Power', 'Source', 'Rechargeable', 'Battery', 'In', 'the', 'Box', '1', 'Mosquito', 'Killer', 'Bat', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Atithee', 'Womens', 'Top', 'and', 'Skirt', 'Set', 'Fabric', '.']
#
#
# ['Key', 'Features', 'of', 'Atithee Womens Top and Skirt Set', 'Fabric', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Lajo', 'Womens', 'Salwar', 'and', 'Kurta', 'Set', 'Fabric', '.']
#
#
# ['Key', 'Features', 'of', 'Lajo Womens Salwar and Kurta Set', 'Fabric', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Moulin', 'Roty', 'Les', 'Petittes', 'Merveilles', 'Nighttime', 'Shadows', 'Castle', '/', '9', 'Type', '.']
#
#
# ['Key', 'Features', 'of', 'Moulin Roty Les Petittes Merveilles Nighttime Shadows Castle  9', '9', 'Type', '.']
#
#
# .......................
# ['Specifications', 'of', 'Doctor', 'Who', 'Prisoner', 'Zero', 'Action', 'Figure', '(', 'Multicolor', ')', 'Important', 'Note', 'The', 'color', 'of', 'some', 'product', 'parts', 'may', 'vary', 'from', 'what', 'is', 'shown', 'in', 'the', 'image', 'General', 'Age', 'Group', '5', '-', '14', 'Years', 'Ideal', 'for', 'Boys', 'Girls', 'Type', 'Action', 'Figure', 'Accessories', 'Character', 'Accessories', '.']
#
#
# ['Specifications', 'of', 'Doctor Who Prisoner Zero Action Figure', '(', 'Multicolor', ')', 'Important', 'Note', 'The', 'color', 'of', 'some', 'product', 'parts', 'may', 'vary', 'from', 'what', 'is', 'shown', 'in', 'the', 'image', 'General', 'Age', 'Group', '5', '-', '14', 'Years', 'Ideal', 'for', 'Boys', 'Girls', 'Type', 'Action', 'Figure', 'Accessories', 'Character', 'Accessories', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Whirlpool', 'Affresh', 'Cooktop', 'Cleaner', 'Kitchen', 'Cleaner', 'THE', '#1', 'SELLING', 'MAJOR', 'APPLIANCE', 'MANUFACTURER', 'IN', 'WORLD', 'RECOMMENDS', 'THIS', 'PRODUCT', 'Non', '-', 'abrasive', 'cleaner', 'is', 'safe', 'for', 'all', 'glass', 'ceramic', 'and', 'porcelain', 'cooktops', 'Cuts', 'through', 'the', 'toughest', 'baked', '-', 'on', 'residue', 'Tested', 'and', 'qualified', 'for', 'use', 'with', 'Ceran', 'glass', 'cooktops', 'Whirlpool', 'Affresh', 'Cooktop', 'Cleaner', 'Kitchen', 'Cleaner', '(', '284', ')', 'Price', '.']
#
#
# ['Key', 'Features', 'of', 'Whirlpool Affresh Cooktop Cleaner Kitchen Cleaner', 'THE', '#1', 'SELLING', 'MAJOR', 'APPLIANCE', 'MANUFACTURER', 'IN', 'WORLD', 'RECOMMENDS', 'THIS', 'PRODUCT', 'Non', '-', 'abrasive', 'cleaner', 'is', 'safe', 'for', 'all', 'glass', 'ceramic', 'and', 'porcelain', 'cooktops', 'Cuts', 'through', 'the', 'toughest', 'baked', '-', 'on', 'residue', 'Tested', 'and', 'qualified', 'for', 'use', 'with', 'Ceran', 'glass', 'cooktops', 'Whirlpool', 'Affresh', 'Cooktop', 'Cleaner', 'Kitchen', 'Cleaner', '(', '284', ')', 'Price', '.']
#
#
# .......................
# ['Sentinel', 'Mak', 'Furige', 'Model', '07', '(', 'Multicolor', ')', 'Price', '.']
#
#
# ['Sentinel Mak Furige Model 07', '(', 'Multicolor', ')', 'Price', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Aroma', 'Comfort', 'Polyester', 'Brown', 'Self', 'Design', 'Eyelet', 'Window', 'Curtain', 'Height', '.']
#
#
# ['Key', 'Features', 'of', 'Aroma Comfort Polyester Brown Self Design Eyelet Window Curtain', 'Height', '.']
#
#
# .......................
# ['Specifications', 'of', 'OMRD', 'RD6697', 'Hot', 'and', 'cold', 'Pack', '(', 'GREEN', ')', 'General', 'Re', '-', 'usable', 'Yes', 'Purpose', 'DRY', 'EYES', 'Area', 'of', 'Use', 'Eyes', '.']
#
#
# ['Specifications', 'of', 'OMRD RD6697 Hot and cold Pack', '(', 'GREEN', ')', 'General', 'Re', '-', 'usable', 'Yes', 'Purpose', 'DRY', 'EYES', 'Area', 'of', 'Use', 'Eyes', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Johhny', 'Cash', '2006', '"Man', 'In', 'Black"', 'Action', '7"', 'Figure', 'Type', '.']
#
#
# ['Key', 'Features', 'of', 'Johhny Cash 2006 Man In Black Action 7 Figure', 'Type', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'AdroitZ', 'Premium', 'Phone', 'Socket', 'Holder', 'For', 'Sony', 'Xperia', 'ZL', 'Type', '.']
#
#
# ['Key', 'Features', 'of', 'AdroitZ Premium Phone Socket Holder For Sony Xperia ZL', 'Type', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'AdroitZ', 'Premium', 'Phone', 'Socket', 'Holder', 'For', 'Samsung', 'ATIV', 'S', 'Type', '.']
#
#
# ['Key', 'Features', 'of', 'AdroitZ Premium Phone Socket Holder For Samsung ATIV S', 'Type', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Hddecor', 'Continental', 'With', '1', 'Meter', 'Flexible', 'Tube', 'And', 'Wall', 'Hook', 'Set', 'Faucet', 'Set', 'Gives', 'an', 'elegant', 'look', 'to', 'your', 'washroom', 'Hddecor', 'Continental', 'With', '1', 'Meter', 'Flexible', 'Tube', 'And', 'Wall', 'Hook', 'Set', 'Faucet', 'Set', 'Price', '.']
#
#
# ['Key', 'Features', 'of', 'Hddecor Continental With 1 Meter Flexible Tube And Wall Hook Set Faucet Set', 'Gives', 'an', 'elegant', 'look', 'to', 'your', 'washroom', 'Hddecor', 'Continental', 'With', '1', 'Meter', 'Flexible', 'Tube', 'And', 'Wall', 'Hook', 'Set', 'Faucet', 'Set', 'Price', '.']
#
#
# .......................
# ['Specifications', 'of', 'Kerastase', 'Nutritive', 'Bain', 'Satin', '1', 'Complete', 'Nutrition', 'Shampoo', '(', '250', 'ml', ')', 'Shampoo', 'Traits', 'Hair', 'Type', 'Dr', 'Hair', 'Normal', 'Hair', 'Applied', 'For', 'Nourishment', '&', 'Moisturization', 'Ideal', 'For', 'Women', 'Men', 'Composition', 'Cationic', 'Polymers', 'Silicone', 'Derivatives', 'General', 'Traits', 'Brand', 'Kerastase', 'Quantity', '250', 'ml', 'Other', 'Traits', 'Smoothes', 'and', 'Protects', 'Hair', 'Leaves', 'Hair', 'Soft', 'Supple', 'Shiny', 'and', 'Manageable', 'Also', 'Ideal', 'for', 'Slightly', 'Sensitive', 'Hair', 'Model', 'Name', 'Nutritive', 'Bain', 'Satin', '1', 'Complete', 'Nutrition', 'Shampoo', 'Container', 'Type', 'Bottle', '.']
#
#
# ['Specifications', 'of', 'Kerastase Nutritive Bain Satin 1 Complete Nutrition Shampoo', '(', '250', 'ml', ')', 'Shampoo', 'Traits', 'Hair', 'Type', 'Dr', 'Hair', 'Normal', 'Hair', 'Applied', 'For', 'Nourishment', '&', 'Moisturization', 'Ideal', 'For', 'Women', 'Men', 'Composition', 'Cationic', 'Polymers', 'Silicone', 'Derivatives', 'General', 'Traits', 'Brand', 'Kerastase', 'Quantity', '250', 'ml', 'Other', 'Traits', 'Smoothes', 'and', 'Protects', 'Hair', 'Leaves', 'Hair', 'Soft', 'Supple', 'Shiny', 'and', 'Manageable', 'Also', 'Ideal', 'for', 'Slightly', 'Sensitive', 'Hair', 'Model', 'Name', 'Nutritive', 'Bain', 'Satin', '1', 'Complete', 'Nutrition', 'Shampoo', 'Container', 'Type', 'Bottle', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'PRINT', 'SHAPES', 'mountain', 'wolf', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', 'Glue', 'Free', 'Removal', '15', '6', 'inches', 'Laptop', 'skin', 'Easy', 'to', 'Apply', '&', 'Scratch', 'Resistant', 'Lamination', 'PRINT', 'SHAPES', 'mountain', 'wolf', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', '(', 'Multicolor', ')', 'Price', '.']
#
#
# ['Key', 'Features', 'of', 'PRINT SHAPES mountain wolf Laptop Skin with Mouse pad Combo Set', 'Glue', 'Free', 'Removal', '15', '6', 'inches', 'Laptop', 'skin', 'Easy', 'to', 'Apply', '&', 'Scratch', 'Resistant', 'Lamination', 'PRINT', 'SHAPES', 'mountain', 'wolf', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', '(', 'Multicolor', ')', 'Price', '.']
#
#
# .......................
# ['Specifications', 'of', 'Goblin', 'Hurricane', 'Expandable', 'Check', '-', 'in', 'Luggage', '-', '25', '9', '(', 'Purple', ')', 'General', 'Closure', 'Zip', 'Luggage', 'Size', '25', '9', 'Cabin', 'Size', 'No', 'Type', 'Check', '-', 'in', 'Luggage', 'Material', 'Nylon', 'Polyester', 'Series', 'Hurricane', 'Style', 'Code', 'Hrc', '65', 'Expandable', 'Feature', 'Yes', 'Capacity', '88', 'L', 'Bag', 'Size', 'Medium', 'Ideal', 'For', 'Boys', 'Men', 'Girls', 'Women', 'Locking', 'Mechanism', 'Number', 'Lock', 'Color', 'Code', 'Purple', 'Dimensions', 'External', 'Depth', '310', 'mm', 'External', 'Width', '470', 'mm', 'Weight', '3800', 'g', 'External', 'Height', '660', 'mm', 'Additional', 'Features', 'STYLISH', '&', 'STIFF', 'EVA', 'Front', 'Panel', 'Laminated', 'with', '420D', 'NYLON', 'FABRIC', '/', '1680D', 'POLYSTER', 'HIGH', 'GLOSS', 'Body', 'Features', 'Number', 'of', 'Pockets', '2', 'Pattern', 'Solid', 'Number', 'of', 'Wheels', '4', 'Other', 'Body', 'Features', '01', 'FULL', 'LENGTH', 'POCKET', '&', '01', 'small', 'Front', 'Zippered', 'Pockets', 'for', 'last', 'minute', 'packing', 'convenience', 'Number', 'of', 'Compartments', '1', '.']
#
#
# ['Specifications', 'of', 'Goblin Hurricane Expandable  Checkin Luggage  259', 'Luggage', '-', '25', '9', '(', 'Purple', ')', 'General', 'Closure', 'Zip', 'Luggage', 'Size', '25', '9', 'Cabin', 'Size', 'No', 'Type', 'Check', '-', 'in', 'Luggage', 'Material', 'Nylon', 'Polyester', 'Series', 'Hurricane', 'Style', 'Code', 'Hrc', '65', 'Expandable', 'Feature', 'Yes', 'Capacity', '88', 'L', 'Bag', 'Size', 'Medium', 'Ideal', 'For', 'Boys', 'Men', 'Girls', 'Women', 'Locking', 'Mechanism', 'Number', 'Lock', 'Color', 'Code', 'Purple', 'Dimensions', 'External', 'Depth', '310', 'mm', 'External', 'Width', '470', 'mm', 'Weight', '3800', 'g', 'External', 'Height', '660', 'mm', 'Additional', 'Features', 'STYLISH', '&', 'STIFF', 'EVA', 'Front', 'Panel', 'Laminated', 'with', '420D', 'NYLON', 'FABRIC', '/', '1680D', 'POLYSTER', 'HIGH', 'GLOSS', 'Body', 'Features', 'Number', 'of', 'Pockets', '2', 'Pattern', 'Solid', 'Number', 'of', 'Wheels', '4', 'Other', 'Body', 'Features', '01', 'FULL', 'LENGTH', 'POCKET', '&', '01', 'small', 'Front', 'Zippered', 'Pockets', 'for', 'last', 'minute', 'packing', 'convenience', 'Number', 'of', 'Compartments', '1', '.']
#
#
# .......................
# ['Specifications', 'of', 'AdroitZ', 'Premium', 'Phone', 'Socket', 'Holder', 'For', 'Galaxy', 'Nexus', '(', 'Red', 'Black', ')', 'General', 'Mount', 'Type', 'Dashboard', 'General', 'Specifications', 'Brand', 'AdroitZ', 'In', 'The', 'Box', 'Car', 'Cradle', 'Model', 'Premium', 'Phone', 'Socket', 'Holder', 'For', 'Galaxy', 'Nexus', 'Color', 'Red', 'Black', '.']
#
#
# ['Specifications', 'of', 'AdroitZ Premium Phone Socket Holder For Galaxy Nexus', '(', 'Red', 'Black', ')', 'General', 'Mount', 'Type', 'Dashboard', 'General', 'Specifications', 'Brand', 'AdroitZ', 'In', 'The', 'Box', 'Car', 'Cradle', 'Model', 'Premium', 'Phone', 'Socket', 'Holder', 'For', 'Galaxy', 'Nexus', 'Color', 'Red', 'Black', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'PRINT', 'SHAPES', 'mary', 'and', 'max', 'cartoon', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', 'Glue', 'Free', 'Removal', '15', '6', 'inches', 'Laptop', 'skin', 'Easy', 'to', 'Apply', '&', 'Scratch', 'Resistant', 'Lamination', 'PRINT', 'SHAPES', 'mary', 'and', 'max', 'cartoon', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', '(', 'Multicolor', ')', 'Price', '.']
#
#
# ['Key', 'Features', 'of', 'PRINT SHAPES mary and max cartoon Laptop Skin with Mouse pad Combo Set', 'Glue', 'Free', 'Removal', '15', '6', 'inches', 'Laptop', 'skin', 'Easy', 'to', 'Apply', '&', 'Scratch', 'Resistant', 'Lamination', 'PRINT', 'SHAPES', 'mary', 'and', 'max', 'cartoon', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', '(', 'Multicolor', ')', 'Price', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Lajo', 'Womens', 'Salwar', 'and', 'Dupatta', 'Set', 'Fabric', '.']
#
#
# ['Key', 'Features', 'of', 'Lajo Womens Salwar and Dupatta Set', 'Fabric', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Aaina', 'Home', 'Decor', 'Cloth', 'Journal', 'FSC', 'certified', 'paper', 'Paper', 'Densitity', '(', 'gsm', ')-', '80', 'Paper', 'Color', '-', 'Off', 'White', 'Paper', 'Size', '-', 'A5', 'Ruled', '-', 'Yes', 'Closure', '-', 'Magnetic', 'closure', 'Extra', 'PocketYes', 'Pen', 'Holder', '-', 'Yes', 'Card', 'Slots', '-', 'Yes', 'Front', 'Cover', 'Design', '-', 'Plain', 'Bookmark', '-', 'Yes', 'Bookmark', 'Type', '-', 'Ribbon', 'Aaina', 'Home', 'Decor', 'Cloth', 'Journal', '(', 'Set', 'Of', '1', 'Green', ')', 'Price', '.']
#
#
# ['Key', 'Features', 'of', 'Aaina Home Decor Cloth Journal', 'FSC', 'certified', 'paper', 'Paper', 'Densitity', '(', 'gsm', ')-', '80', 'Paper', 'Color', '-', 'Off', 'White', 'Paper', 'Size', '-', 'A5', 'Ruled', '-', 'Yes', 'Closure', '-', 'Magnetic', 'closure', 'Extra', 'PocketYes', 'Pen', 'Holder', '-', 'Yes', 'Card', 'Slots', '-', 'Yes', 'Front', 'Cover', 'Design', '-', 'Plain', 'Bookmark', '-', 'Yes', 'Bookmark', 'Type', '-', 'Ribbon', 'Aaina', 'Home', 'Decor', 'Cloth', 'Journal', '(', 'Set', 'Of', '1', 'Green', ')', 'Price', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'PRINT', 'SHAPES', 'Batman', 'vs', 'red', 'superman', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', 'Glue', 'Free', 'Removal', '15', '6', 'inches', 'Laptop', 'skin', 'Easy', 'to', 'Apply', '&', 'Scratch', 'Resistant', 'Lamination', 'PRINT', 'SHAPES', 'Batman', 'vs', 'red', 'superman', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', '(', 'Multicolor', ')', 'Price', '.']
#
#
# ['Key', 'Features', 'of', 'PRINT SHAPES Batman vs red superman Laptop Skin with Mouse pad Combo Set', 'Glue', 'Free', 'Removal', '15', '6', 'inches', 'Laptop', 'skin', 'Easy', 'to', 'Apply', '&', 'Scratch', 'Resistant', 'Lamination', 'PRINT', 'SHAPES', 'Batman', 'vs', 'red', 'superman', 'Laptop', 'Skin', 'with', 'Mouse', 'pad', 'Combo', 'Set', '(', 'Multicolor', ')', 'Price', '.']
#
#
# .......................
# ['Specifications', 'of', 'Predator', 'Official', 'Licensed7"', 'Vs', 'Dutch', '2', 'Pack', '(', 'Multicolor', ')', 'Important', 'Note', 'The', 'color', 'of', 'some', 'product', 'parts', 'may', 'vary', 'from', 'what', 'is', 'shown', 'in', 'the', 'image', 'General', 'Character', 'Predator', 'vs', 'dutch', '.']
#
#
# ['Specifications', 'of', 'Predator Official Licensed7 Vs Dutch 2 Pack', '(', 'Multicolor', ')', 'Important', 'Note', 'The', 'color', 'of', 'some', 'product', 'parts', 'may', 'vary', 'from', 'what', 'is', 'shown', 'in', 'the', 'image', 'General', 'Character', 'Predator', 'vs', 'dutch', '.']
#
#
# .......................
# ['sark', 'NO015', 'Faucet', 'Set', 'Price', '.']
#
#
# ['sark NO015 Faucet Set', 'Price', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'happy', 'deals', '36', 'Crazy', 'Loop', 'Straws', '-', 'value', 'pack', '-', 'assorted', 'color', 'Type', '.']
#
#
# ['Key', 'Features', 'of', 'happy deals 36 Crazy Loop Straws value pack  assorted color', 'assorted', 'color', 'Type', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Lajo', 'Womens', 'Salwar', 'and', 'Dupatta', 'Set', 'Fabric', '.']
#
#
# ['Key', 'Features', 'of', 'Lajo Womens Salwar and Dupatta Set', 'Fabric', '.']
#
#
# .......................
# ['Specifications', 'of', 'Lip', 'Rageous', 'Blue', 'Raspberry', 'LipBalm', '4', '25g', 'Blue', 'Raspberry', '(', '4', '25', 'g', ')', 'Lip', 'Balm', 'Traits', 'Flavor', 'Blue', 'Raspberry', 'General', 'Traits', 'Organic', 'Type', 'Natural', 'Quantity', '4', '25', 'g', 'Shade', 'blue', 'Ideal', 'For', 'Women', 'In', 'the', 'Box', '6', 'Lip', 'Balm', '.']
#
#
# ['Specifications', 'of', 'Lip Rageous Blue Raspberry LipBalm 425g Blue Raspberry', 'Raspberry', '(', '4', '25', 'g', ')', 'Lip', 'Balm', 'Traits', 'Flavor', 'Blue', 'Raspberry', 'General', 'Traits', 'Organic', 'Type', 'Natural', 'Quantity', '4', '25', 'g', 'Shade', 'blue', 'Ideal', 'For', 'Women', 'In', 'the', 'Box', '6', 'Lip', 'Balm', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Sitaram', 'Womens', 'Top', 'and', 'Skirt', 'Set', 'Georgette', 'material', 'Zari', 'embrodery', 'long', 'kurta', 'long', 'sleeeves', 'With', 'georgette', 'dupatta', 'Sitaram', 'Womens', 'Top', 'and', 'Skirt', 'Set', 'Price', '.']
#
#
# ['Key', 'Features', 'of', 'Sitaram Womens Top and Skirt Set', 'Georgette', 'material', 'Zari', 'embrodery', 'long', 'kurta', 'long', 'sleeeves', 'With', 'georgette', 'dupatta', 'Sitaram', 'Womens', 'Top', 'and', 'Skirt', 'Set', 'Price', '.']
#
#
# .......................
# ['Specifications', 'of', 'Chap', 'Ice', 'Chap', 'Ice', 'Tropical', 'SPF', '-', '30', 'Lip', 'Balm', 'six', 'different', 'fruit', 'flavor', '(', '4', '25', 'g', ')', 'Lip', 'Balm', 'Traits', 'Flavor', 'six', 'different', 'fruit', 'flavor', 'General', 'Traits', 'Organic', 'Type', 'Natural', 'Quantity', '4', '25', 'g', 'Shade', 'Green', 'Ideal', 'For', 'Women', 'In', 'the', 'Box', '1', 'Lip', 'Balm', '.']
#
#
# ['Specifications', 'of', 'Chap Ice Chap Ice Tropical SPF30 Lip Balm six different fruit flavor', 'fruit', 'flavor', '(', '4', '25', 'g', ')', 'Lip', 'Balm', 'Traits', 'Flavor', 'six', 'different', 'fruit', 'flavor', 'General', 'Traits', 'Organic', 'Type', 'Natural', 'Quantity', '4', '25', 'g', 'Shade', 'Green', 'Ideal', 'For', 'Women', 'In', 'the', 'Box', '1', 'Lip', 'Balm', '.']
#
#
# .......................
# ['Key', 'Features', 'of', 'Nourish', 'Cardboard', '2', '-', 'O', '-', 'Folder', 'Compatible', 'Paper', 'Size', '.']
#
#
# ['Key', 'Features', 'of', 'Nourish Cardboard 2O Folder', 'O', '-', 'Folder', 'Compatible', 'Paper', 'Size', '.']
#
#
# .......................
# ['Specifications', 'of', 'Nourish', 'Cardboard', '2', '-', 'D', '-', 'Folder', '(', 'Set', 'Of', '1', 'Multicoloured', ')', 'General', 'Build', 'Material', 'Cardboard', 'Type', '2', '-', 'D', '-', 'Folder', 'Model', 'Name', 'RB24', 'Compatible', 'Paper', 'Size', 'A4', 'Dimensions', 'Spine', 'Width', '40', 'mm', 'Height', '305', 'mm', 'Width', '255', 'mm', 'Features', 'Inner', 'Pockets', '1', 'Inner', 'Pockets', 'In', 'the', 'Box', 'FILE', 'FOLDER', 'PAPER', 'COMPRESSOR', 'SEPARATORS', 'STICKERS', '.']
#
#
# ...
#
#
# ['Buy', 'Wallmantra Medium Vinyl Stickers Sticker', 'for', '623', 'online', 'Wallmantra', 'Medium', 'Vinyl', 'Stickers', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................
# ['Buy', 'WallDesign', 'Small', 'Vinyl', 'Sticker', 'for', '720', 'online', 'WallDesign', 'Small', 'Vinyl', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# ['Buy', 'WallDesign Small Vinyl Sticker', 'for', '720', 'online', 'WallDesign', 'Small', 'Vinyl', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................
# ['Buy', 'Wallmantra', 'Large', 'Vinyl', 'Stickers', 'Sticker', 'for', '1143', 'online', 'Wallmantra', 'Large', 'Vinyl', 'Stickers', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# ['Buy', 'Wallmantra Large Vinyl Stickers Sticker', 'for', '1143', 'online', 'Wallmantra', 'Large', 'Vinyl', 'Stickers', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................
# ['Buy', 'Wallmantra', 'Extra', 'Large', 'Vinyl', 'Stickers', 'Sticker', 'for', '2229', 'online', 'Wallmantra', 'Extra', 'Large', 'Vinyl', 'Stickers', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# ['Buy', 'Wallmantra Extra Large Vinyl Stickers Sticker', 'for', '2229', 'online', 'Wallmantra', 'Extra', 'Large', 'Vinyl', 'Stickers', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................
# ['Buy', 'Wallmantra', 'Extra', 'Large', 'Vinyl', 'Stickers', 'Sticker', 'for', '840', 'online', 'Wallmantra', 'Extra', 'Large', 'Vinyl', 'Stickers', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# ['Buy', 'Wallmantra Extra Large Vinyl Stickers Sticker', 'for', '840', 'online', 'Wallmantra', 'Extra', 'Large', 'Vinyl', 'Stickers', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................
# ['Uberlyfe', 'Extra', 'Large', 'Vinyl', 'Sticker', '(', 'Pack', 'of', '2', ')', 'Price', '.']
#
#
# ['Uberlyfe Extra Large Vinyl Sticker', '(', 'Pack', 'of', '2', ')', 'Price', '.']
#
#
# .......................
# ['Buy', 'Wallmantra', 'Large', 'Vinyl', 'Stickers', 'Sticker', 'for', '1143', 'online', 'Wallmantra', 'Large', 'Vinyl', 'Stickers', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# ['Buy', 'Wallmantra Large Vinyl Stickers Sticker', 'for', '1143', 'online', 'Wallmantra', 'Large', 'Vinyl', 'Stickers', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................
# ['Buy', 'WallDesign', 'Small', 'Vinyl', 'Sticker', 'for', '730', 'online', 'WallDesign', 'Small', 'Vinyl', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# ['Buy', 'WallDesign Small Vinyl Sticker', 'for', '730', 'online', 'WallDesign', 'Small', 'Vinyl', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................
# ['Buy', 'WallDesign', 'Small', 'Vinyl', 'Sticker', 'for', '510', 'online', 'WallDesign', 'Small', 'Vinyl', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# ['Buy', 'WallDesign Small Vinyl Sticker', 'for', '510', 'online', 'WallDesign', 'Small', 'Vinyl', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................
# ['WallDesign', 'Small', 'Vinyl', 'Sticker', '(', 'Pack', 'of', '75', ')', 'Price', '.']
#
#
# ['WallDesign Small Vinyl Sticker', '(', 'Pack', 'of', '75', ')', 'Price', '.']
#
#
# .......................
# ['Buy', 'WallDesign', 'Small', 'Vinyl', 'Sticker', 'for', '530', 'online', 'WallDesign', 'Small', 'Vinyl', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# ['Buy', 'WallDesign Small Vinyl Sticker', 'for', '530', 'online', 'WallDesign', 'Small', 'Vinyl', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................
# ['Wallmantra', 'Large', 'Vinyl', 'Sticker', 'Sticker', '(', 'Pack', 'of', '1', ')', 'Price', '.']
#
#
# ['Wallmantra Large Vinyl Sticker Sticker', '(', 'Pack', 'of', '1', ')', 'Price', '.']
#
#
# .......................
# ['Buy', '999store', 'Medium', 'Paper', 'Sticker', 'for', '599', 'online', '999store', 'Medium', 'Paper', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# ['Buy', '999store Medium Paper Sticker', 'for', '599', 'online', '999store', 'Medium', 'Paper', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................
# ['Buy', 'Elite', 'Collection', 'Medium', 'Acrylic', 'Sticker', 'for', '999', 'online', 'Elite', 'Collection', 'Medium', 'Acrylic', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# ['Buy', 'Elite Collection Medium Acrylic Sticker', 'for', '999', 'online', 'Elite', 'Collection', 'Medium', 'Acrylic', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................
# ['Buy', '999store', 'Medium', 'Paper', 'Sticker', 'for', '599', 'online', '999store', 'Medium', 'Paper', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# ['Buy', '999store Medium Paper Sticker', 'for', '599', 'online', '999store', 'Medium', 'Paper', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................
# ['Buy', 'WallDesign', 'Small', 'Vinyl', 'Sticker', 'for', '600', 'online', 'WallDesign', 'Small', 'Vinyl', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# ['Buy', 'WallDesign Small Vinyl Sticker', 'for', '600', 'online', 'WallDesign', 'Small', 'Vinyl', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................
# ['Buy', 'Wallmantra', 'Extra', 'Large', 'Vinyl', 'Stickers', 'Sticker', 'for', '1216', 'online', 'Wallmantra', 'Extra', 'Large', 'Vinyl', 'Stickers', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# ['Buy', 'Wallmantra Extra Large Vinyl Stickers Sticker', 'for', '1216', 'online', 'Wallmantra', 'Extra', 'Large', 'Vinyl', 'Stickers', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................
# ['Buy', 'WallDesign', 'Small', 'Vinyl', 'Sticker', 'for', '640', 'online', 'WallDesign', 'Small', 'Vinyl', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# ['Buy', 'WallDesign Small Vinyl Sticker', 'for', '640', 'online', 'WallDesign', 'Small', 'Vinyl', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................
# ['Buy', '999store', 'Medium', 'Paper', 'Sticker', 'for', '599', 'online', '999store', 'Medium', 'Paper', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# ['Buy', '999store Medium Paper Sticker', 'for', '599', 'online', '999store', 'Medium', 'Paper', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................
# ['Buy', 'Elite', 'Collection', 'Medium', 'Acrylic', 'Sticker', 'for', '999', 'online', 'Elite', 'Collection', 'Medium', 'Acrylic', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# ['Buy', 'Elite Collection Medium Acrylic Sticker', 'for', '999', 'online', 'Elite', 'Collection', 'Medium', 'Acrylic', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................
# ['Buy', 'WallDesign', 'Small', 'Vinyl', 'Sticker', 'for', '600', 'online', 'WallDesign', 'Small', 'Vinyl', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# ['Buy', 'WallDesign Small Vinyl Sticker', 'for', '600', 'online', 'WallDesign', 'Small', 'Vinyl', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................
# ['Buy', '999store', 'Medium', 'Paper', 'Sticker', 'for', '599', 'online', '999store', 'Medium', 'Paper', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# ['Buy', '999store Medium Paper Sticker', 'for', '599', 'online', '999store', 'Medium', 'Paper', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................
# ['Buy', 'Elite', 'Collection', 'Medium', 'Acrylic', 'Sticker', 'for', '999', 'online', 'Elite', 'Collection', 'Medium', 'Acrylic', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# ['Buy', 'Elite Collection Medium Acrylic Sticker', 'for', '999', 'online', 'Elite', 'Collection', 'Medium', 'Acrylic', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................
# ['Buy', 'Wallmantra', 'Large', 'Vinyl', 'Stickers', 'Sticker', 'for', '582', 'online', 'Wallmantra', 'Large', 'Vinyl', 'Stickers', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# ['Buy', 'Wallmantra Large Vinyl Stickers Sticker', 'for', '582', 'online', 'Wallmantra', 'Large', 'Vinyl', 'Stickers', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................
# ['Buy', 'WallDesign', 'Small', 'Vinyl', 'Sticker', 'for', '730', 'online', 'WallDesign', 'Small', 'Vinyl', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# ['Buy', 'WallDesign Small Vinyl Sticker', 'for', '730', 'online', 'WallDesign', 'Small', 'Vinyl', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................
# ['Buy', 'Wallmantra', 'Large', 'Vinyl', 'Stickers', 'Sticker', 'for', '1143', 'online', 'Wallmantra', 'Large', 'Vinyl', 'Stickers', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# ['Buy', 'Wallmantra Large Vinyl Stickers Sticker', 'for', '1143', 'online', 'Wallmantra', 'Large', 'Vinyl', 'Stickers', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................
# ['Buy', 'Elite', 'Collection', 'Medium', 'Acrylic', 'Sticker', 'for', '999', 'online', 'Elite', 'Collection', 'Medium', 'Acrylic', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# ['Buy', 'Elite Collection Medium Acrylic Sticker', 'for', '999', 'online', 'Elite', 'Collection', 'Medium', 'Acrylic', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................
# ['Buy', 'Elite', 'Collection', 'Medium', 'Acrylic', 'Sticker', 'for', '1199', 'online', 'Elite', 'Collection', 'Medium', 'Acrylic', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# ['Buy', 'Elite Collection Medium Acrylic Sticker', 'for', '1199', 'online', 'Elite', 'Collection', 'Medium', 'Acrylic', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................
# ['Buy', 'Elite', 'Collection', 'Medium', 'Acrylic', 'Sticker', 'for', '999', 'online', 'Elite', 'Collection', 'Medium', 'Acrylic', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# ['Buy', 'Elite Collection Medium Acrylic Sticker', 'for', '999', 'online', 'Elite', 'Collection', 'Medium', 'Acrylic', 'Sticker', 'at', 'best', 'prices', 'with', 'FREE', 'shipping', '&', 'cash', 'on', 'delivery', 'Only', 'Genuine', 'Products', '30', 'Day', 'Replacement', 'Guarantee', '.']
#
#
# .......................

# %%
data_list_product = data_preparation(product_df)

# %%
# create a file name called new_df.json and write the data.
import json
with open("/content/drive/MyDrive/datasets/flipkart_products.json", "w") as f:
  for item in data_list_product:
    f.write(json.dumps(item))
    f.write("\n")

# %% [markdown]
# trial version dataframe and check whether everything is working fine

# %%
# sample_df = new_df[:20]

# %%
# trial_df = sample_df.copy()

# %%
# create a file name called new_df.json and write the data.
# import json
# with open("/content/drive/MyDrive/test_data/test_df.json", "w") as f:
#   for item in sample_list:
#     f.write(json.dumps(item))
#     f.write("\n")

# %%
# test_df = sample_df.copy()

# %%
# trial_df["TEXT"]

# %%
# def test_df_trail(test_df):
  
#   new_list = []
#   for index, row in test_df.iterrows():
#     # print(row)
#     first_list = row["TEXT"][0].copy()
#     # print("This is first list in a row")
#     print("\n")
#     print(first_list)
#     print(row["Name_ID"])
#     name_list = row["Name_ID"].split()
#     print(name_list)
#     join_token = name_list[0]
#     name_length = len(name_list)
#     print("lenght of name_list={}".format(name_length))
#     print(join_token)
#     if join_token in first_list:
#       print("hello")
#       try:
#         word_index = first_list.index(join_token)
#         print("word_index", word_index)
#       except ValueError as e:
#         print(e)
#       else:
#         # for i in range(word_index, name_length-1):
#         del first_list[word_index:word_index+name_length]
#         print("\n")
#         print(".......................")
#         print(first_list)
#         first_list.insert(word_index, row["Name_ID"])
#         print(first_list)
#         print("\n")
#         row["TEXT"][0] = first_list
#         test_df.at[index, "TEXT"]=row["TEXT"]
#         # row["TEXT"][0] = first_list
#         # new_list.append(first_list)
#         print(row["TEXT"])
#   print("test_df")
#   return test_df

# %%
# test_df_new = test_df_trail(trial_df)

# %%
# new_test_df_list = data_preparation(test_df_new)

# %%
# # create a file name called new_df.json and write the data.
# import json
# with open("/content/drive/MyDrive/test_data/new_test_df.json", "w") as f:
#   for item in new_test_df_list:
#     f.write(json.dumps(item))
#     f.write("\n")
