# %% [markdown]
# <a href="https://colab.research.google.com/github/priya170807/text_analysis/blob/master/slot_attention_product_latest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import os
# os.kill(os.getpid(), 9)

# %%
from google.colab import drive
drive.flush_and_unmount()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # New section

# %% [markdown]
# # New section

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !ls -l
# Out:
# total 551619
# drwx------ 2 root root      4096 Jan 27  2020 "Aditi's function_photos"
# drwx------ 2 root root      4096 Dec  6  2019 'Colab Notebooks'
# -rw------- 1 root root     69337 Jan  5 00:14  datacleaning_flipkart.ipynb
# drwx------ 2 root root      4096 Jun 25  2019  datasets
# drwx------ 8 root root      4096 Dec 30 07:03  Describing_a_Knowledge_Base
# drwx------ 2 root root      4096 Dec  6  2019  jupyter_notebooks
# -r-------- 1 root root      1497 Jun  4  2018 'M1 Codes.zip'
# -r-------- 1 root root      5372 Jun 12  2018 'M2 codes.zip'
# -rw------- 1 root root 177897472 Jun 10  2017  M2U00107.MPG
# -rw------- 1 root root 386859008 Jun 10  2017  M2U00116.MPG
# drwx------ 2 root root      4096 Jan  4 20:10  test_data

# %%
# !rm -r /content/drive/MyDrive/Describing_a_knowledge_base
# Out:
# rm: cannot remove '/content/drive/MyDrive/Describing_a_knowledge_base': No such file or directory

# %%
# !git clone https://github.com/EagleW/Describing_a_Knowledge_Base.git
# Out:
# Cloning into 'Describing_a_Knowledge_Base'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 65 (delta 3), reused 1 (delta 0), pack-reused 56
# Unpacking objects: 100% (65/65), done.

# %%
# !pwd
# Out:
# /content/drive/My Drive

# %%
# !ls -la
# Out:
# total 551610
# drwx------ 2 root root      4096 Jan 27  2020 "Aditi's function_photos"
# drwx------ 2 root root      4096 Dec  6  2019 'Colab Notebooks'
# -rw------- 1 root root     64068 Dec 30 06:57  datacleaning_flipkart.ipynb
# drwx------ 2 root root      4096 Jun 25  2019  datasets
# drwx------ 6 root root      4096 Dec 30 07:03  Describing_a_Knowledge_Base
# drwx------ 2 root root      4096 Dec  6  2019  jupyter_notebooks
# -r-------- 1 root root      1497 Jun  4  2018 'M1 Codes.zip'
# -r-------- 1 root root      5372 Jun 12  2018 'M2 codes.zip'
# -rw------- 1 root root 177897472 Jun 10  2017  M2U00107.MPG
# -rw------- 1 root root 386859008 Jun 10  2017  M2U00116.MPG

# %%
# %cd /content/drive/MyDrive/Describing_a_Knowledge_Base
# !gdown --id 1TzcNdjZ0EsLh_rC1pBC7dU70jINcsVJd
# Out:
# /content/drive/MyDrive/Describing_a_Knowledge_Base
# Downloading...
# From: https://drive.google.com/uc?id=1TzcNdjZ0EsLh_rC1pBC7dU70jINcsVJd
# To: /content/drive/MyDrive/Describing_a_Knowledge_Base/Wiki_dataset.zip
# 265MB [00:01, 135MB/s]

# %%
# !ls -l
# Out:
# total 259626
# -rw------- 1 root root      2840 Dec 30 07:03 eval_final.py
# -rw------- 1 root root      2849 Dec 30 07:03 eval.py
# -rw------- 1 root root      1069 Dec 30 07:03 LICENSE
# -rw------- 1 root root      9351 Dec 30 07:03 main.py
# -rw------- 1 root root      7302 Dec 30 07:03 predictor.py
# drwx------ 2 root root      4096 Dec 30 07:34 __pycache__
# drwx------ 2 root root      4096 Dec 30 07:03 pycocoevalcap
# -rw------- 1 root root      2634 Dec 30 07:03 README.md
# drwx------ 2 root root      4096 Dec 30 07:03 structure_generator
# -rw------- 1 root root        53 Dec 30 07:34 test_A.pkl
# -rw------- 1 root root    273916 Dec 30 07:34 train_A.pkl
# drwx------ 2 root root      4096 Dec 30 07:03 utils
# -rw------- 1 root root        53 Dec 30 07:34 valid_A.pkl
# -rw------- 1 root root     54973 Dec 30 07:34 vocab_D.pkl
# drwx------ 3 root root      4096 Jan  4 18:00 Wiki_dataset
# -rw------- 1 root root 265477748 Jan  4 18:09 Wiki_dataset.zip

# %%
# !unzip /content/drive/MyDrive/Describing_a_Knowledge_Base/Wiki_dataset.zip -d /content/drive/MyDrive/Describing_a_Knowledge_Base/Wiki_dataset/
# Out:
# Archive:  /content/drive/MyDrive/Describing_a_Knowledge_Base/Wiki_dataset.zip
# replace /content/drive/MyDrive/Describing_a_Knowledge_Base/Wiki_dataset/wiki_person.json? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace /content/drive/MyDrive/Describing_a_Knowledge_Base/Wiki_dataset/wiki_animal.json? [y]es, [n]o, [A]ll, [N]one, [r]ename: n

# %%
# %cd /content/drive/MyDrive/Describing_a_Knowledge_Base/utils
# !python /content/drive/MyDrive/Describing_a_Knowledge_Base/utils/split.py
# Out:
# /content/drive/MyDrive/Describing_a_Knowledge_Base/utils
# the length of file 20000
# the length of train 16000
# the length of valid 18000
# the length of training 16000
# the length of validing 2000
# the length of testing 2000
# Finished Animal train
# Finished Animal valid
# Finished Animal test
# the length of file 428748
# the length of train 342992
# the length of valid 385870
# the length of training 342992
# the length of validing 42878
# the length of testing 42878
# Finished Person train
# Finished Person valid
# Finished Person test

# %%
# %cd /content/drive/MyDrive/Describing_a_Knowledge_Base/utils
# !python preprocess.py --type 1
# Out:
# /content/drive/MyDrive/Describing_a_Knowledge_Base/utils
# Finish read text
# 409
# Finish dump
# Finish read text
# 0
# Finish dump
# Finish read text
# 0
# Finish dump

# %%
# %cd /content/drive/MyDrive/Describing_a_Knowledge_Base/
# !pwd
# !python main.py --cuda --mode 0 --type 1
# Out:
# /content/drive/MyDrive/Describing_a_Knowledge_Base
# /content/drive/MyDrive/Describing_a_Knowledge_Base
# Finish build vocabulary
# Finish build word dictionary
# number of training examples: 409
# start training...
# /content/drive/MyDrive/Describing_a_Knowledge_Base/structure_generator/DecoderRNN.py:75: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/LegacyDefinitions.cpp:28.)
#   attn_scores.data.masked_fill_(enc_mask.data.byte(), -10000.0)
# Finished epoch 1 with losses: 12.1758
# Start Evaluating
# Result:
# ref {}
# Traceback (most recent call last):
#   File "main.py", line 151, in <module>
#     train_epoches(t_dataset, v_dataset, model, config.epochs, 1)
#   File "main.py", line 136, in train_epoches
#     print('ref: ', ref[1][0])
# KeyError: 1

# %%
import pickle

file = pickle.load(open('/content/drive/MyDrive/Describing_a_Knowledge_Base/train_A.pkl', 'rb'))

# %%
file
# Out:
# {'maxp': 5,
#  'source': [[('Name_ID', 'AW Bellies', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'AW', 3)],
#   [('Name_ID',
#     'BuildTrack PIR Wireless Motion Sensor - One Switch Control Wireless Sensor Security System',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'BuildTrack', 3)],
#   [('Name_ID', "Babeezworld Dungaree Baby Boy's  Combo", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Babeezworld', 3)],
#   [('Name_ID', 'JASPO Saphire Dual Shoe Skates Combo Size 5 Skating Kit', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'JASPO', 3)],
#   [('Name_ID', 'JQR JQR Sports Shoes Running Shoes', 1),
#    ('parent taxon', 'JQR', 2),
#    ('instance of', 'Footwear', 3)],
#   [('Name_ID', 'JQR JQR Sports Shoes Running Shoes', 1),
#    ('parent taxon', 'JQR', 2),
#    ('instance of', 'Footwear', 3)],
#   [('Name_ID', 'Karatcraft Twinoh Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Karatcraft', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Karatcraft Solitana Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Karatcraft', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Karatcraft Celebra Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Karatcraft', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Karatcraft Journa Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Karatcraft', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Karatcraft Wadell Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Karatcraft', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Karatcraft Triniya Promise Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Karatcraft', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Karatcraft Citra Engagement Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Karatcraft', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Karatcraft Ailey Band Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Karatcraft', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Karatcraft Clariz Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Karatcraft', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Karatcraft Trilic Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Karatcraft', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Allure Silver Amethyst Sterling Silver Ring', 1),
#    ('parent taxon', 'Allure', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Karatcraft Duma Stackable Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Karatcraft', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID',
#     'Myesquire Black and White Aroma Burner Combo Lemongrass Liquid Air Freshener',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Myesquire', 3)],
#   [('Name_ID', 'Karatcraft Citra Engagement Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Karatcraft', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Karatcraft Raciel Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Karatcraft', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID',
#     'Myesquire Blue Green Aroma Burner Combo Lemongrass Liquid Air Freshener',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Myesquire', 3)],
#   [('Name_ID',
#     'Myesquire White Brown Aroma Burner Combo Lemongrass Liquid Air Freshener',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Myesquire', 3)],
#   [('Name_ID',
#     "Tullis Women's Purple, Pink, Green, Blue, Red, Black Leggings",
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Tullis', 3)],
#   [('Name_ID',
#     "Tullis Women's White, Purple, Pink, Green, Blue, Green Leggings",
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Tullis', 3)],
#   [('Name_ID', 'CarSizzler Car Storage Bag', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'CarSizzler', 3)],
#   [('Name_ID', 'Dinoimpex Balloon and Beyblade Set Combo', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Dinoimpex', 3)],
#   [('Name_ID', 'Leebo LED Headlight For Bajaj Pulsar 150', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Leebo', 3)],
#   [('Name_ID', 'Leebo LED Headlight For Honda CB', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Leebo', 3)],
#   [('Name_ID', 'Leebo LED Headlight For Suzuki Sling', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Leebo', 3)],
#   [('Name_ID', 'PUSHCART REK-164-W W-B-MSG Massager', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'PUSHCART', 3)],
#   [('Name_ID', 'dgold Beads Stone Necklace', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'dgold', 3)],
#   [('Name_ID', 'dgold Quartz Stone Necklace', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'dgold', 3)],
#   [('Name_ID', 'Dgold Onyx Stone Necklace Set', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Dgold', 3)],
#   [('Name_ID', 'dgold Beads Stone Necklace', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'dgold', 3)],
#   [('Name_ID', 'CHKOKKO Chains Alloy Necklace', 1),
#    ('parent taxon', 'CHKOKKO', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'dgold Spinel Stone Necklace', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'dgold', 3)],
#   [('Name_ID', 'dgold Citrine Stone Necklace', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'dgold', 3)],
#   [('Name_ID', 'dgold Beads Stone Necklace', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'dgold', 3)],
#   [('Name_ID', 'dgold Garnet Stone Necklace', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'dgold', 3)],
#   [('Name_ID', "HEAVENLY Dress Baby Boy's  Combo", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'HEAVENLY', 3)],
#   [('Name_ID', 'Parinaaz Alloy Mangalsutra', 1),
#    ('parent taxon', 'Parinaaz', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Decon Metal Mangalsutra', 1),
#    ('parent taxon', 'Decon', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Parinaaz Alloy Mangalsutra', 1),
#    ('parent taxon', 'Parinaaz', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Parinaaz Alloy Mangalsutra', 1),
#    ('parent taxon', 'Parinaaz', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Parinaaz Alloy Mangalsutra', 1),
#    ('parent taxon', 'Parinaaz', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Decon Alloy Mangalsutra', 1),
#    ('parent taxon', 'Decon', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Parinaaz Alloy Mangalsutra', 1),
#    ('parent taxon', 'Parinaaz', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'TUP Book Cover for Alcatel One Touch Tab 7 7 Inch', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'TUP', 3)],
#   [('Name_ID', 'Jewels5 Alena Yellow Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Jewels5', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'TUP Flip Cover for Stand Milagrow 7.16/7.16 pro 7 Inch', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'TUP', 3)],
#   [('Name_ID', 'Jewels5 Adan Yellow Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Jewels5', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', "Royal Men's Kurta and Pyjama Set", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Royal', 3)],
#   [('Name_ID', "Royal Men's Kurta and Pyjama Set", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Royal', 3)],
#   [('Name_ID', "Royal Men's Pathani Suit Set", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Royal', 3)],
#   [('Name_ID', 'IBALL ZPS-290 450 Watts PSU', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'IBALL', 3)],
#   [('Name_ID', 'GLAMWALK Festive Bellies', 1),
#    ('parent taxon', 'GLAMWALK', 2),
#    ('instance of', 'Footwear', 3)],
#   [('Name_ID', 'Remix Yellow-Pin Brooch', 1),
#    ('parent taxon', 'Remix', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', "VRTYA Casual Short Sleeve Solid Women's Grey Top", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'VRTYA', 3)],
#   [('Name_ID', "VRTYA Casual Sleeveless Solid Women's Blue Top", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'VRTYA', 3)],
#   [('Name_ID', 'Micromax  Battery - Canvas Fire A093', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Micromax', 3)],
#   [('Name_ID', "VRTYA Casual Sleeveless Solid Women's Black Top", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'VRTYA', 3)],
#   [('Name_ID', "VRTYA Casual Short Sleeve Solid Women's Grey Top", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'VRTYA', 3)],
#   [('Name_ID', "VRTYA Casual Sleeveless Solid Women's Red Top", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'VRTYA', 3)],
#   [('Name_ID', 'BELL BLEP-D10 Earphone Cable Organizer', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'BELL', 3)],
#   [('Name_ID', 'HERDY Aviator Sunglasses', 1),
#    ('parent taxon', 'HERDY', 2),
#    ('instance of', 'Sunglasses', 3)],
#   [('Name_ID', 'Zyaden Oval Sunglasses', 1),
#    ('parent taxon', 'Zyaden', 2),
#    ('instance of', 'Sunglasses', 3)],
#   [('Name_ID', 'Elligator Aviator Sunglasses', 1),
#    ('parent taxon', 'Elligator', 2),
#    ('instance of', 'Sunglasses', 3)],
#   [('Name_ID', 'Zyaden Oval Sunglasses', 1),
#    ('parent taxon', 'Zyaden', 2),
#    ('instance of', 'Sunglasses', 3)],
#   [('Name_ID', 'HERDY Aviator Sunglasses', 1),
#    ('parent taxon', 'HERDY', 2),
#    ('instance of', 'Sunglasses', 3)],
#   [('Name_ID', "Lilliput Top Baby Girl's  Combo", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Lilliput', 3)],
#   [('Name_ID', "Lilliput Top Baby Girl's  Combo", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Lilliput', 3)],
#   [('Name_ID', "Lilliput Top Baby Girl's  Combo", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Lilliput', 3)],
#   [('Name_ID', "Lilliput Top Baby Girl's  Combo", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Lilliput', 3)],
#   [('Name_ID', "Lilliput Top Baby Girl's  Combo", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Lilliput', 3)],
#   [('Name_ID', "Lilliput Top Baby Girl's  Combo", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Lilliput', 3)],
#   [('Name_ID', "Lilliput Top Baby Girl's  Combo", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Lilliput', 3)],
#   [('Name_ID', "Lilliput Top Baby Girl's  Combo", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Lilliput', 3)],
#   [('Name_ID',
#     'Voylla Artificial Classic Plain Yellow Gold Plated Alloy Necklace',
#     1),
#    ('parent taxon', 'Voylla', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID',
#     'Voylla Artificial Classic Plain Crystal Yellow Gold Plated Alloy Necklace',
#     1),
#    ('parent taxon', 'Voylla', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID',
#     'Voylla Artificial Beaded Plain Yellow Gold Plated Alloy Necklace',
#     1),
#    ('parent taxon', 'Voylla', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID',
#     'Shoppingtara Kundan Meenakari Marble Mobile Stand With Clock Showpiece  -  8 cm',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Shoppingtara', 3)],
#   [('Name_ID', 'Technotech Q3 Wireless Optical Mouse Gaming Mouse', 1),
#    ('parent taxon', 'Technotech', 2),
#    ('instance of', 'Gaming', 3)],
#   [('Name_ID', 'Ocean Q3 Wireless Optical Mouse Gaming Mouse', 1),
#    ('parent taxon', 'Ocean', 2),
#    ('instance of', 'Gaming', 3)],
#   [('Name_ID', "Romano Full Sleeve Solid Women's Sweatshirt", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Romano', 3)],
#   [('Name_ID',
#     'Dhrohar Black Geometric Irregular Yellow Gold Plated Alloy Necklace',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Dhrohar', 3)],
#   [('Name_ID', 'Hawai Rings Ensemble Fashion Jewellery Alloy Necklace', 1),
#    ('parent taxon', 'Hawai', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Hawai Rings Fashion Jewellery (Golden) Alloy Necklace', 1),
#    ('parent taxon', 'Hawai', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Hawai Ring Alert Fashion Jewellery Alloy Necklace', 1),
#    ('parent taxon', 'Hawai', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Dgold Onyx Stone Necklace', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Dgold', 3)],
#   [('Name_ID', 'Intex 5 Feet Swimming Pool With Hand Pump', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Intex', 3)],
#   [('Name_ID', 'ZeroKaata Alloy Armlet', 1),
#    ('parent taxon', 'ZeroKaata', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'ocean VGLASS0051', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'ocean', 3)],
#   [('Name_ID', "Romano Full Sleeve Striped Men's Sweatshirt", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Romano', 3)],
#   [('Name_ID', "Romano Full Sleeve Striped Men's Sweatshirt", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Romano', 3)],
#   [('Name_ID', 'Mikado Aviator Sunglasses', 1),
#    ('parent taxon', 'Mikado', 2),
#    ('instance of', 'Sunglasses', 3)],
#   [('Name_ID', 'Damemoda Wayfarer Sunglasses', 1),
#    ('parent taxon', 'Damemoda', 2),
#    ('instance of', 'Sunglasses', 3)],
#   [('Name_ID', 'Damemoda Wayfarer Sunglasses', 1),
#    ('parent taxon', 'Damemoda', 2),
#    ('instance of', 'Sunglasses', 3)],
#   [('Name_ID', 'HH Oval Sunglasses', 1),
#    ('parent taxon', 'HH', 2),
#    ('instance of', 'Sunglasses', 3)],
#   [('Name_ID', 'HH Wayfarer Sunglasses', 1),
#    ('parent taxon', 'HH', 2),
#    ('instance of', 'Sunglasses', 3)],
#   [('Name_ID', 'Aligatorr Aviator Sunglasses', 1),
#    ('parent taxon', 'Aligatorr', 2),
#    ('instance of', 'Sunglasses', 3)],
#   [('Name_ID', 'HH Aviator Sunglasses', 1),
#    ('parent taxon', 'HH', 2),
#    ('instance of', 'Sunglasses', 3)],
#   [('Name_ID', 'Aria Rhodium Sterling Silver Pendant', 1),
#    ('parent taxon', 'Aria', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Aria Rhodium Sterling Silver Pendant', 1),
#    ('parent taxon', 'Aria', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Aria Rhodium Sterling Silver Pendant', 1),
#    ('parent taxon', 'Aria', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Aria Rhodium Sterling Silver Pendant', 1),
#    ('parent taxon', 'Aria', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Aria Rhodium Sterling Silver Pendant', 1),
#    ('parent taxon', 'Aria', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'INAYA Yellow Gold NAK Brass Pendant Set', 1),
#    ('parent taxon', 'INAYA', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Aria Rhodium Sterling Silver Pendant', 1),
#    ('parent taxon', 'Aria', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Aria Rhodium Sterling Silver Pendant', 1),
#    ('parent taxon', 'Aria', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'INAYA Yellow Gold NAK Brass Pendant Set', 1),
#    ('parent taxon', 'INAYA', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Marami 9 10 7  - 13 inch', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Marami', 3)],
#   [('Name_ID', 'ShellysTrends Planters Plant Container Set', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'ShellysTrends', 3)],
#   [('Name_ID', 'ShellysTrends Planters Plant Container Set', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'ShellysTrends', 3)],
#   [('Name_ID', 'ShellysTrends Planters Plant Container Set', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'ShellysTrends', 3)],
#   [('Name_ID', 'Amscan 117801.1 Plastic Weight Sled', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Amscan', 3)],
#   [('Name_ID', 'ShellysTrends Planters Plant Container Set', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'ShellysTrends', 3)],
#   [('Name_ID', 'ShellysTrends Planters Plant Container Set', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'ShellysTrends', 3)],
#   [('Name_ID', 'ShellysTrends Planters Plant Container Set', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'ShellysTrends', 3)],
#   [('Name_ID', 'ShellysTrends Planters Plant Container Set', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'ShellysTrends', 3)],
#   [('Name_ID', "HEAVENLY Dress Baby Boy's  Combo", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'HEAVENLY', 3)],
#   [('Name_ID', 'Olvin Wayfarer Sunglasses', 1),
#    ('parent taxon', 'Olvin', 2),
#    ('instance of', 'Sunglasses', 3)],
#   [('Name_ID', 'Olvin Oval Sunglasses', 1),
#    ('parent taxon', 'Olvin', 2),
#    ('instance of', 'Sunglasses', 3)],
#   [('Name_ID', 'Olvin Aviator Sunglasses', 1),
#    ('parent taxon', 'Olvin', 2),
#    ('instance of', 'Sunglasses', 3)],
#   [('Name_ID', 'Olvin Aviator Sunglasses', 1),
#    ('parent taxon', 'Olvin', 2),
#    ('instance of', 'Sunglasses', 3)],
#   [('Name_ID', 'Flipside Flip Flops', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Flipside', 3)],
#   [('Name_ID', 'Naaz The Young Scientist for kids Board Game', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Naaz', 3)],
#   [('Name_ID', 'Naaz International Buisness Game Board Game', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Naaz', 3)],
#   [('Name_ID', 'Naaz Dart game Board Game', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Naaz', 3)],
#   [('Name_ID', 'Naaz 2 in 1 Paper Quilling Board Game', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Naaz', 3)],
#   [('Name_ID', 'Flipside Flip Flops', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Flipside', 3)],
#   [('Name_ID', 'Naaz Tic Tac Toe mini Board Game', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Naaz', 3)],
#   [('Name_ID', 'Naaz Manicure Pedicure Kit For Kids and adult Board Game', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Naaz', 3)],
#   [('Name_ID', 'Jewels5 Daliah Yellow Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Jewels5', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Jewels5 Tanessa Yellow Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Jewels5', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID',
#     'GB Jewellery Artistic Alloy Cubic Zirconia Yellow Gold Ring',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID',
#     'GB Jewellery Luxurious Alloy Cubic Zirconia Yellow Gold Ring',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', "dongli Night Suit Boy's  Combo", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'dongli', 3)],
#   [('Name_ID', "dongli Night Suit Boy's  Combo", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'dongli', 3)],
#   [('Name_ID', "dongli Night Suit Boy's  Combo", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'dongli', 3)],
#   [('Name_ID', 'Anuradha Art Designer Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Scion Floral Saree Pin Quilling Brooch', 1),
#    ('parent taxon', 'Scion', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Stylish Designer Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'misshruts An Emerald Brooch Brooch', 1),
#    ('parent taxon', 'misshruts', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Gato Chief Tan Corporate Casuals', 1),
#    ('parent taxon', 'Gato', 2),
#    ('instance of', 'Footwear', 3)],
#   [('Name_ID', 'Taraash Sterling Silver Jewel Set', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Taraash', 3),
#    ('instance of', 'Jewellery', 4)],
#   [('Name_ID', 'Magic 22K Yellow Gold Plated Brass Chain', 1),
#    ('parent taxon', 'Magic', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Magic 22K Yellow Gold Plated Brass Chain', 1),
#    ('parent taxon', 'Magic', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'STERN KS34SRI SPINE ROLL Massager', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'STERN', 3)],
#   [('Name_ID',
#     'CPEX Thrive 20 IN 1 Facial Megantic Face Pain Relif Thrive Massager',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'CPEX', 3)],
#   [('Name_ID', 'Anuradha Art ZBF-263 Hair Clip', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', "FIFO Bottom Women's  Combo", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'FIFO', 3)],
#   [('Name_ID', "FIFO Bottom Women's  Combo", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'FIFO', 3)],
#   [('Name_ID',
#     'Kozdiko Premium Quality Centre Console Black Color RMA8 Car Armrest',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Kozdiko', 3)],
#   [('Name_ID', 'CHKOKKO Alloy Chain', 1),
#    ('parent taxon', 'CHKOKKO', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Tennis Tennis Sports Shoes Running Shoes', 1),
#    ('parent taxon', 'Tennis', 2),
#    ('instance of', 'Footwear', 3)],
#   [('Name_ID', 'Mentiezi Red Flower Brooch', 1),
#    ('parent taxon', 'Mentiezi', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Mentiezi Black Flower with Green Leave Brooch', 1),
#    ('parent taxon', 'Mentiezi', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Samaa S-0003 Brooch', 1),
#    ('parent taxon', 'Samaa', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Ruvee Marwari Tika Brooch', 1),
#    ('parent taxon', 'Ruvee', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Antique Golden Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Mentiezi Blue Maroon Flower Brooch', 1),
#    ('parent taxon', 'Mentiezi', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'gurjari oxidised kurta button brooch Brooch', 1),
#    ('parent taxon', 'gurjari', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Antique Golden Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID',
#     "SENECIO 'S 1Pair Partywear Punk Feather Angel Wings Style Best Gift Collar Pin Gold Plated Unisex Brooch",
#     1),
#    ('parent taxon', 'SENECIO', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'ANAHI SAREE PIN Brooch', 1),
#    ('parent taxon', 'ANAHI', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Variation Diamond Flowers Brooch', 1),
#    ('parent taxon', 'Variation', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Shihibas Belly Button Piercing Brooch', 1),
#    ('parent taxon', 'Shihibas', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Mivera Brooch', 1),
#    ('parent taxon', 'Mivera', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Antique Golden Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'gurjari oxidiesd kurta button brooch Brooch', 1),
#    ('parent taxon', 'gurjari', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'ANAHI SAREE PIN Brooch', 1),
#    ('parent taxon', 'ANAHI', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Variation Diamond Flowers Brooch', 1),
#    ('parent taxon', 'Variation', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Ruvee Marwari Style Brooch', 1),
#    ('parent taxon', 'Ruvee', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'gurjari oxidiesd kutra button brooch Brooch', 1),
#    ('parent taxon', 'gurjari', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Variation Diamond Flowers Brooch', 1),
#    ('parent taxon', 'Variation', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Antique Golden Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Variation Diamond Flowers Brooch', 1),
#    ('parent taxon', 'Variation', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Antique Golden Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Anuradha Art Silver Polished Brooch', 1),
#    ('taxon rank', 'Product', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Koie  Battery - For Samsung 7562 Premium Quality', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Koie', 3)],
#   [('Name_ID', 'K&N 1 Bike Spark Plug, 1 Air Filter-TVS Sport Combo', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'K&N', 3)],
#   [('Name_ID', 'Shopernow Medallions Alloy Necklace', 1),
#    ('parent taxon', 'Shopernow', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Shopernow Intertwined Alloy Necklace', 1),
#    ('parent taxon', 'Shopernow', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID',
#     'Speedwav 1 Car Bumper Sticker, 1 Napoleon Air Freshener Combo',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Speedwav', 3)],
#   [('Name_ID', 'Shopernow Cocktail Designer Alloy Necklace', 1),
#    ('parent taxon', 'Shopernow', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID',
#     'K&N 1 Bike Spark Plug, 1 Air Filter-Honda CB Trigger Combo',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'K&N', 3)],
#   [('Name_ID', "Creez Solid Women's Charcoal Full Length Sports Tights", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Creez', 3)],
#   [('Name_ID', 'Koie  Battery - For Samsung S2 Premium Quality', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Koie', 3)],
#   [('Name_ID',
#     'Xtreme 3 Pipe Air Pressure For Hero Karizma 110 dB Vehicle Horn',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Xtreme', 3)],
#   [('Name_ID',
#     'Speedwav Single Pipe Car Air Pressure -HM Ambassador MPFi 200 dB Vehicle Horn',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Speedwav', 3)],
#   [('Name_ID',
#     'Speedwav Single Pipe Car Air Pressure -Nissan Micra 200 dB Vehicle Horn',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Speedwav', 3)],
#   [('Name_ID',
#     'Speedwav Twin Tone 2 Pipe Car Air Pressure -Hyundai Verna Type 1 200 dB Vehicle Horn',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Speedwav', 3)],
#   [('Name_ID',
#     'Xtreme 3 Pipe Air Pressure For Honda Activa 110 dB Vehicle Horn',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Xtreme', 3)],
#   [('Name_ID',
#     'Speedwav Single Pipe Air Pressure Horn-Chevrolet Cruze Type 2 110 dB Vehicle Horn',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Speedwav', 3)],
#   [('Name_ID',
#     'Xtreme 3 Pipe Air Pressure For Hero HF 110 dB Vehicle Horn',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Xtreme', 3)],
#   [('Name_ID',
#     'Speedwav Single Pipe Car Air Pressure -Skoda Yeti 200 dB Vehicle Horn',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Speedwav', 3)],
#   [('Name_ID', 'Jojo Book Cover for Orange Tahiti', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Jojo', 3)],
#   [('Name_ID', 'iCare Flip Cover for Universal Rotate 7 inch Tablet', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'iCare', 3)],
#   [('Name_ID',
#     'Speedwav Single Pipe Car Air Pressure -Maruti Kizashi 200 dB Vehicle Horn',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Speedwav', 3)],
#   [('Name_ID',
#     'Speedwav Single Pipe Car Air Pressure -Nissan Patrol 200 dB Vehicle Horn',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Speedwav', 3)],
#   [('Name_ID',
#     'Speedwav Single Pipe Car Air Pressure -Chevrolet Aveo 200 dB Vehicle Horn',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Speedwav', 3)],
#   [('Name_ID', 'Xtreme MB Windtone For Bajaj Pulsar 110 dB Vehicle Horn', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Xtreme', 3)],
#   [('Name_ID', 'Kuhuk Plastic Bangle Set', 1),
#    ('parent taxon', 'Kuhuk', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Jojo Book Cover for ZTE V9', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Jojo', 3)],
#   [('Name_ID',
#     'Xtreme MB Windtone For Royal Enfield Electra EFI39 110 dB Vehicle Horn',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Xtreme', 3)],
#   [('Name_ID', 'Xtreme MB Windtone For TVS Pep Plus 110 dB Vehicle Horn', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Xtreme', 3)],
#   [('Name_ID', 'Jojo Flip Cover for Prestigio Multipad 7.0 Ultra +', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Jojo', 3)],
#   [('Name_ID',
#     'Speedwav Twin Tone 2 Pipe Car Air Pressure -Fiat Palio 200 dB Vehicle Horn',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Speedwav', 3)],
#   [('Name_ID',
#     'Xtreme MB Windtone For Bajaj Discover 100 DTS-i 110 dB Vehicle Horn',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Xtreme', 3)],
#   [('Name_ID', 'Jojo Book Cover for Samsung\xa0Galaxy Tab 2 P3110 (16Gb)', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Jojo', 3)],
#   [('Name_ID',
#     'Speedwav Twin Tone 2 Pipe Car Air Pressure -Tata Safari Type 1 200 dB Vehicle Horn',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Speedwav', 3)],
#   [('Name_ID', 'Jojo Book Cover for Prestigio Multipad 7.0 Prime Duo 3G', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Jojo', 3)],
#   [('Name_ID', "Kalt Self Design Round Neck Casual Women's Sweater", 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Kalt', 3)],
#   [('Name_ID', 'Kuhuk Plastic Bangle Set', 1),
#    ('parent taxon', 'Kuhuk', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Kuhuk Plastic Bangle Set', 1),
#    ('parent taxon', 'Kuhuk', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Kuhuk Plastic Bangle Set', 1),
#    ('parent taxon', 'Kuhuk', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Kuhuk Plastic Bangle Set', 1),
#    ('parent taxon', 'Kuhuk', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Airwind Xylophone001', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Airwind', 3)],
#   [('Name_ID', 'Jewels5 Davita Yellow Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Jewels5', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Karatcraft Triniya Promise Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Karatcraft', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Jewels5 Jaidon Yellow Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Jewels5', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Jewels5 Ganesha Gold Diamond Rhodium 14 K Ring', 1),
#    ('parent taxon', 'Jewels5', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Jewels5 Karasel Yellow Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Jewels5', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Jewels5 Jaelyn Yellow Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Jewels5', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Karatcraft Clariz Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Karatcraft', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Jewels5 Lavatera Yellow Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Jewels5', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Karatcraft Twinoh Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Karatcraft', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Jewels5 Makale Yellow Gold Diamond 18 K Ring', 1),
#    ('parent taxon', 'Jewels5', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'MSL Trendy Loafers', 1),
#    ('parent taxon', 'MSL', 2),
#    ('instance of', 'Footwear', 3)],
#   [('Name_ID', 'AYESHA Metal Chain', 1),
#    ('parent taxon', 'AYESHA', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'Pavvoin Lingerie Set', 1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'Pavvoin', 3)],
#   [('Name_ID',
#     'You2Deal Wood & Iron Handicraft Antique Style Home Decor Cycle Gift Item Showpiece  -  25 cm',
#     1),
#    ('taxon rank', 'Product', 2),
#    ('parent taxon', 'You2Deal', 3)],
#   [('Name_ID', 'JewelFox Gold Tanmaniya', 1),
#    ('parent taxon', 'JewelFox', 2),
#    ('instance of', 'Jewellery', 3)],
#   [('Name_ID', 'JewelFox Gold Tanmaniya', 1),
#    ('parent taxon', 'JewelFox', 2),
#    ('instance of', 'Jewellery', 3)]],
#  'target': [['',
#    'Manufacturer',
#    'Product',
#    'Warranty',
#    'against',
#    'manufacturing',
#    'defects',
#    '',
#    '.',
#    'Key',
#    'Features',
#    'of',
#    'AW',
#    'Bellies',
#    'Sandals',
#    'Wedges',
#    'Heel',
#    'Casuals',
#    '',
#    'AW',
#    'Bellies',
#    'Price',
#    '',
#    '.',
#    '',
#    'do',
#    'not',
#    'use',
#    'polish',
#    'or',
#    'shiner',
#    '',
#    'Specifications',
#    'of',
#    'AW',
#    'Bellies',
#    'General',
#    'Ideal',
#    'For',
#    'Women',
#    'Occasion',
#    'Casual',
#    'Shoe',
#    'Details',
#    'Color',
#    'Red',
#    'Outer',
#    'Material',
#    'Patent',
#    'Leather',
#    'Heel',
#    'Height',
#    '1',
#    'inch',
#    'Number',
#    'of',
#    'Contents',
#    'in',
#    'Sales',
#    'Package',
#    'Pack',
#    'of',
#    '1',
#    'In',
#    'the',
#    'Box',
#    'One',
#    'Pair',
#    'Of',
#    'Shoes',
#    '.'],
#   ['Key',
#    'Features',
#    'of',
#    'BuildTrack',
#    'PIR',
#    'Wireless',
#    'Motion',
#    'Sensor',
#    '-',
#    'One',
#    'Switch',
#    'Control',
#    'Wireless',
#    'Sensor',
#    'Security',
#    'System',
#    'National',
#    'Award',
#    'Winning',
#    'Product',
#    'Long',
#    'Battery',
#    'Life',
#    'Freely',
#    'Placed',
#    'Low',
#    'Power',
#    'Consumed',
#    '',
#    'BuildTrack',
#    'PIR',
#    'Wireless',
#    'Motion',
#    'Sensor',
#    '-',
#    'One',
#    'Switch',
#    'Control',
#    'Wireless',
#    'Sensor',
#    'Security',
#    'System',
#    'Price',
#    '',
#    '.'],
#   ['Specifications',
#    'of',
#    'Babeezworld',
#    'Dungaree',
#    'Baby',
#    'Boys',
#    'Combo',
#    'Apparel',
#    'Combo',
#    'Details',
#    'Primary',
#    'Product',
#    'Size',
#    'S',
#    'Fabric',
#    'Cotton',
#    'Pattern',
#    'Printed',
#    'Fit',
#    'Regular',
#    'Fit',
#    'Occasion',
#    'Casual',
#    'Ideal',
#    'For',
#    'Baby',
#    'Boys',
#    'Additional',
#    'Details',
#    'Style',
#    'Code',
#    'bbz1105a',
#    'Fabric',
#    'Care',
#    'Wash',
#    'with',
#    'Similar',
#    'Colors',
#    '',
#    'Use',
#    'Detergent',
#    'for',
#    'Colors',
#    'In',
#    'the',
#    'Box',
#    'Number',
#    'of',
#    'Contents',
#    'in',
#    'Sales',
#    'Package',
#    '2',
#    '.'],
#   ['Specifications',
#    'of',
#    'JASPO',
#    'Saphire',
#    'Dual',
#    'Shoe',
#    'Skates',
#    'Combo',
#    'Size',
#    '5',
#    'Skating',
#    'Kit',
#    'General',
#    'Sport',
#    'Type',
#    'Skating',
#    'Ideal',
#    'for',
#    'Senior',
#    'Color',
#    'Orange',
#    'Important',
#    'Note',
#    'Cancellation',
#    'NOT',
#    'allowed',
#    'for',
#    'this',
#    'product',
#    'after',
#    '24',
#    'hrs',
#    'of',
#    'order',
#    'booking',
#    'Dimensions',
#    'Height',
#    '23',
#    'cm',
#    'Width',
#    '26',
#    'cm',
#    'Depth',
#    '34',
#    'cm',
#    'In',
#    'the',
#    'Box',
#    'Sales',
#    'Package',
#    'Shoe',
#    'Skate',
#    '',
#    'Helmet',
#    '',
#    'Bag',
#    'Additional',
#    'Features',
#    'This',
#    'Combo',
#    'Is',
#    'A',
#    'Definite',
#    'Must',
#    '-',
#    'Have',
#    'For',
#    'Beginners',
#    'And',
#    'Learners',
#    'A',
#    'Perfect',
#    'Product',
#    'For',
#    'Gifting',
#    'Too',
#    '.'],
#   ['',
#    'These',
#    'Footwear',
#    'Have',
#    'Been',
#    'Designed',
#    'Keeping',
#    'The',
#    'Needs',
#    'Of',
#    'TodayS',
#    'Youth',
#    'In',
#    'Mind',
#    '',
#    'Specifications',
#    'of',
#    'JQR',
#    'JQR',
#    'Sports',
#    'Shoes',
#    'Running',
#    'Shoes',
#    'General',
#    'Occasion',
#    'Sports',
#    'Ideal',
#    'For',
#    'Men',
#    'Shoe',
#    'Details',
#    'Sole',
#    'Material',
#    'Phylon',
#    'Weight',
#    '840',
#    'g',
#    '(',
#    'per',
#    'single',
#    'Shoe',
#    ')',
#    '-',
#    'Weight',
#    'of',
#    'the',
#    'product',
#    'may',
#    'vary',
#    'depending',
#    'on',
#    'size',
#    'Heel',
#    'Height',
#    '1',
#    'inch',
#    'Outer',
#    'Material',
#    'Synthetic',
#    'Leather',
#    'Color',
#    'Black',
#    '',
#    'Red',
#    'Additional',
#    'Details',
#    'Care',
#    'Instructions',
#    'Wash',
#    'in',
#    'Lukewarm',
#    'Water',
#    '',
#    'Do',
#    'Not',
#    'Bleach',
#    '.',
#    'Key',
#    'Features',
#    'of',
#    'JQR',
#    'JQR',
#    'Sports',
#    'Shoes',
#    'Running',
#    'Shoes',
#    'Material',
#    '',
#    '.'],
#   ['',
#    'These',
#    'Footwear',
#    'Have',
#    'Been',
#    'Designed',
#    'Keeping',
#    'The',
#    'Needs',
#    'Of',
#    'TodayS',
#    'Youth',
#    'In',
#    'Mind',
#    '',
#    'Specifications',
#    'of',
#    'JQR',
#    'JQR',
#    'Sports',
#    'Shoes',
#    'Running',
#    'Shoes',
#    'General',
#    'Occasion',
#    'Sports',
#    'Ideal',
#    'For',
#    'Men',
#    'Shoe',
#    'Details',
#    'Sole',
#    'Material',
#    'Phylon',
#    'Weight',
#    '840',
#    'g',
#    '(',
#    'per',
#    'single',
#    'Shoe',
#    ')',
#    '-',
#    'Weight',
#    'of',
#    'the',
#    'product',
#    'may',
#    'vary',
#    'depending',
#    'on',
#    'size',
#    'Heel',
#    'Height',
#    '1',
#    'inch',
#    'Outer',
#    'Material',
#    'Synthetic',
#    'Leather',
#    'Color',
#    'Blue',
#    '',
#    'Silver',
#    'Additional',
#    'Details',
#    'Care',
#    'Instructions',
#    'Wash',
#    'in',
#    'Lukewarm',
#    'Water',
#    '',
#    'Do',
#    'Not',
#    'Bleach',
#    '.',
#    'Key',
#    'Features',
#    'of',
#    'JQR',
#    'JQR',
#    'Sports',
#    'Shoes',
#    'Running',
#    'Shoes',
#    'Material',
#    '',
#    '.'],
#   ['Karatcraft',
#    'Twinoh',
#    'Gold',
#    'Diamond',
#    '18',
#    'K',
#    'Ring',
#    'Price',
#    '',
#    '.',
#    '',
#    '20672',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
#    'marvel',
#    'For',
#    'the',
#    'connoisseur',
#    'like',
#    'you',
#    'this',
#    'is',
#    'a',
#    'perfect',
#    'piece',
#    'of',
#    'Diamond',
#    'Jewellery',
#    'to',
#    'flaunt',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
#    'marvel',
#    'For',
#    'the',
#    'connoisseur',
#    'like',
#    'you',
#    'this',
#    'is',
#    'a',
#    'perfect',
#    'piece',
#    'of',
#    'Diamond',
#    'Jewellery',
#    'to',
#    'flaunt',
#    '.'],
#   ['Karatcraft',
#    'Solitana',
#    'Gold',
#    'Diamond',
#    '18',
#    'K',
#    'Ring',
#    'Price',
#    '',
#    '.',
#    '',
#    '20749',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
#    'marvel',
#    'For',
#    'the',
#    'connoisseur',
#    'like',
#    'you',
#    'this',
#    'is',
#    'a',
#    'perfect',
#    'piece',
#    'of',
#    'Diamond',
#    'Jewellery',
#    'to',
#    'flaunt',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
#    'marvel',
#    'For',
#    'the',
#    'connoisseur',
#    'like',
#    'you',
#    'this',
#    'is',
#    'a',
#    'perfect',
#    'piece',
#    'of',
#    'Diamond',
#    'Jewellery',
#    'to',
#    'flaunt',
#    '.'],
#   ['Karatcraft',
#    'Celebra',
#    'Gold',
#    'Diamond',
#    '18',
#    'K',
#    'Ring',
#    'Price',
#    '',
#    '.',
#    '',
#    '20586',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
#    'marvel',
#    'For',
#    'the',
#    'connoisseur',
#    'like',
#    'you',
#    'this',
#    'is',
#    'a',
#    'perfect',
#    'piece',
#    'of',
#    'Diamond',
#    'Jewellery',
#    'to',
#    'flaunt',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
#    'marvel',
#    'For',
#    'the',
#    'connoisseur',
#    'like',
#    'you',
#    'this',
#    'is',
#    'a',
#    'perfect',
#    'piece',
#    'of',
#    'Diamond',
#    'Jewellery',
#    'to',
#    'flaunt',
#    '.'],
#   ['Karatcraft',
#    'Journa',
#    'Gold',
#    'Diamond',
#    '18',
#    'K',
#    'Ring',
#    'Price',
#    '',
#    '.',
#    '',
#    '37787',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
#    'marvel',
#    'For',
#    'the',
#    'connoisseur',
#    'like',
#    'you',
#    'this',
#    'is',
#    'a',
#    'perfect',
#    'piece',
#    'of',
#    'Diamond',
#    'Jewellery',
#    'to',
#    'flaunt',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
#    'marvel',
#    'For',
#    'the',
#    'connoisseur',
#    'like',
#    'you',
#    'this',
#    'is',
#    'a',
#    'perfect',
#    'piece',
#    'of',
#    'Diamond',
#    'Jewellery',
#    'to',
#    'flaunt',
#    '.'],
#   ['Karatcraft',
#    'Wadell',
#    'Gold',
#    'Diamond',
#    '18',
#    'K',
#    'Ring',
#    'Price',
#    '',
#    '.',
#    '',
#    '30741',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
#    'marvel',
#    'For',
#    'the',
#    'connoisseur',
#    'like',
#    'you',
#    'this',
#    'is',
#    'a',
#    'perfect',
#    'piece',
#    'of',
#    'Diamond',
#    'Jewellery',
#    'to',
#    'flaunt',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
#    'marvel',
#    'For',
#    'the',
#    'connoisseur',
#    'like',
#    'you',
#    'this',
#    'is',
#    'a',
#    'perfect',
#    'piece',
#    'of',
#    'Diamond',
#    'Jewellery',
#    'to',
#    'flaunt',
#    '.'],
#   ['Karatcraft',
#    'Triniya',
#    'Promise',
#    'Gold',
#    'Diamond',
#    '18',
#    'K',
#    'Ring',
#    'Price',
#    '',
#    '.',
#    '',
#    '28011',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
#    'marvel',
#    'For',
#    'the',
#    'connoisseur',
#    'like',
#    'you',
#    'this',
#    'is',
#    'a',
#    'perfect',
#    'piece',
#    'of',
#    'Diamond',
#    'Jewellery',
#    'to',
#    'flaunt',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
#    'marvel',
#    'For',
#    'the',
#    'connoisseur',
#    'like',
#    'you',
#    'this',
#    'is',
#    'a',
#    'perfect',
#    'piece',
#    'of',
#    'Diamond',
#    'Jewellery',
#    'to',
#    'flaunt',
#    '.'],
#   ['Karatcraft',
#    'Citra',
#    'Engagement',
#    'Gold',
#    'Diamond',
#    '18',
#    'K',
#    'Ring',
#    'Price',
#    '',
#    '.',
#    '',
#    '33298',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
#    'marvel',
#    'For',
#    'the',
#    'connoisseur',
#    'like',
#    'you',
#    'this',
#    'is',
#    'a',
#    'perfect',
#    'piece',
#    'of',
#    'Diamond',
#    'Jewellery',
#    'to',
#    'flaunt',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
#    'marvel',
#    'For',
#    'the',
#    'connoisseur',
#    'like',
#    'you',
#    'this',
#    'is',
#    'a',
#    'perfect',
#    'piece',
#    'of',
#    'Diamond',
#    'Jewellery',
#    'to',
#    'flaunt',
#    '.'],
#   ['Karatcraft',
#    'Ailey',
#    'Band',
#    'Gold',
#    'Diamond',
#    '18',
#    'K',
#    'Ring',
#    'Price',
#    '',
#    '.',
#    '',
#    '33702',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
#    'marvel',
#    'For',
#    'the',
#    'connoisseur',
#    'like',
#    'you',
#    'this',
#    'is',
#    'a',
#    'perfect',
#    'piece',
#    'of',
#    'Diamond',
#    'Jewellery',
#    'to',
#    'flaunt',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
#    'marvel',
#    'For',
#    'the',
#    'connoisseur',
#    'like',
#    'you',
#    'this',
#    'is',
#    'a',
#    'perfect',
#    'piece',
#    'of',
#    'Diamond',
#    'Jewellery',
#    'to',
#    'flaunt',
#    '.'],
#   ['Karatcraft',
#    'Clariz',
#    'Gold',
#    'Diamond',
#    '18',
#    'K',
#    'Ring',
#    'Price',
#    '',
#    '.',
#    '',
#    '38964',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
#    'marvel',
#    'For',
#    'the',
#    'connoisseur',
#    'like',
#    'you',
#    'this',
#    'is',
#    'a',
#    'perfect',
#    'piece',
#    'of',
#    'Diamond',
#    'Jewellery',
#    'to',
#    'flaunt',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
#    'marvel',
#    'For',
#    'the',
#    'connoisseur',
#    'like',
#    'you',
#    'this',
#    'is',
#    'a',
#    'perfect',
#    'piece',
#    'of',
#    'Diamond',
#    'Jewellery',
#    'to',
#    'flaunt',
#    '.'],
#   ['Karatcraft',
#    'Trilic',
#    'Gold',
#    'Diamond',
#    '18',
#    'K',
#    'Ring',
#    'Price',
#    '',
#    '.',
#    '',
#    '33761',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
#    'marvel',
#    'For',
#    'the',
#    'connoisseur',
#    'like',
#    'you',
#    'this',
#    'is',
#    'a',
#    'perfect',
#    'piece',
#    'of',
#    'Diamond',
#    'Jewellery',
#    'to',
#    'flaunt',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
# ...
#    '285',
#    'Product',
#    'Details',
#    '',
#    '.'],
#   ['Speedwav',
#    'Twin',
#    'Tone',
#    '2',
#    'Pipe',
#    'Car',
#    'Air',
#    'Pressure',
#    '-',
#    'Fiat',
#    'Palio',
#    '200',
#    'dB',
#    'Vehicle',
#    'Horn',
#    'Price',
#    '',
#    '.',
#    '',
#    'Product',
#    'color',
#    'may',
#    'vary',
#    'as',
#    'per',
#    'stock',
#    'availability',
#    'Package',
#    'Contents',
#    '',
#    '.',
#    '',
#    'Product',
#    'color',
#    'may',
#    'vary',
#    'as',
#    'per',
#    'stock',
#    'availability',
#    'Package',
#    'Contents',
#    '',
#    '.'],
#   ['Xtreme',
#    'MB',
#    'Windtone',
#    'For',
#    'Bajaj',
#    'Discover',
#    '100',
#    'DTS',
#    '-',
#    'i',
#    '110',
#    'dB',
#    'Vehicle',
#    'Horn',
#    'Price',
#    '',
#    '.',
#    '',
#    '110DB',
#    'TYPE',
#    'ELECTRIC',
#    'HORN',
#    'SPEAKER',
#    'DESIGN',
#    '4',
#    '-',
#    'WAY',
#    '100%',
#    'Original',
#    'Product',
#    'from',
#    'MOCC',
#    'FUNDAMENTAL',
#    'FREQUENCY',
#    '',
#    '.',
#    '',
#    '110DB',
#    'TYPE',
#    'ELECTRIC',
#    'HORN',
#    'SPEAKER',
#    'DESIGN',
#    '4',
#    '-',
#    'WAY',
#    '100%',
#    'Original',
#    'Product',
#    'from',
#    'MOCC',
#    'FUNDAMENTAL',
#    'FREQUENCY',
#    '',
#    '.'],
#   ['Jojo',
#    'Book',
#    'Cover',
#    'for',
#    'Samsung\xa0Galaxy',
#    'Tab',
#    '2',
#    'P3110',
#    '(',
#    '16Gb',
#    ')',
#    '(',
#    'Baby',
#    'Pink',
#    ')',
#    'Price',
#    '',
#    '.',
#    '',
#    '285',
#    'Product',
#    'Details',
#    '',
#    '.'],
#   ['Speedwav',
#    'Twin',
#    'Tone',
#    '2',
#    'Pipe',
#    'Car',
#    'Air',
#    'Pressure',
#    '-',
#    'Tata',
#    'Safari',
#    'Type',
#    '1',
#    '200',
#    'dB',
#    'Vehicle',
#    'Horn',
#    'Price',
#    '',
#    '.',
#    '',
#    'Product',
#    'color',
#    'may',
#    'vary',
#    'as',
#    'per',
#    'stock',
#    'availability',
#    'Package',
#    'Contents',
#    '',
#    '.',
#    '',
#    'Product',
#    'color',
#    'may',
#    'vary',
#    'as',
#    'per',
#    'stock',
#    'availability',
#    'Package',
#    'Contents',
#    '',
#    '.'],
#   ['Jojo',
#    'Book',
#    'Cover',
#    'for',
#    'Prestigio',
#    'Multipad',
#    '7',
#    '0',
#    'Prime',
#    'Duo',
#    '3G',
#    '(',
#    'Smokey',
#    'Black',
#    ')',
#    'Price',
#    '',
#    '.',
#    '',
#    '285',
#    'Product',
#    'Details',
#    '',
#    '.'],
#   ['Specifications',
#    'of',
#    'Kalt',
#    'Self',
#    'Design',
#    'Round',
#    'Neck',
#    'Casual',
#    'Womens',
#    'Sweater',
#    'Sweater',
#    'Details',
#    'Hooded',
#    'No',
#    'Sleeve',
#    'Full',
#    'Sleeve',
#    'Number',
#    'of',
#    'Contents',
#    'in',
#    'Sales',
#    'Package',
#    'Pack',
#    'of',
#    '1',
#    'Reversible',
#    'No',
#    'Fabric',
#    'Cotton',
#    'Weave',
#    'Type',
#    'Jacquard',
#    'Neck',
#    'Round',
#    'Neck',
#    'General',
#    'Details',
#    'Pattern',
#    'Self',
#    'Design',
#    'Ideal',
#    'For',
#    'Womens',
#    'Occasion',
#    'Casual',
#    'Fabric',
#    'Care',
#    'Product',
#    'May',
#    'Slightly',
#    'Vary',
#    'Due',
#    'To',
#    'Photographic',
#    'Lighting',
#    'Sources',
#    'Or',
#    'Your',
#    'Monitor',
#    'Settings',
#    'Tumble',
#    'Dry',
#    '',
#    'Do',
#    'Not',
#    'Sun',
#    'Dry',
#    '',
#    'Do',
#    'Not',
#    'Wring',
#    '',
#    'Do',
#    'Not',
#    'Line',
#    'Dry',
#    '',
#    'Use',
#    'Steam',
#    'Iron',
#    'For',
#    'Best',
#    'Results',
#    '',
#    'Machine',
#    'Wash',
#    'With',
#    'Detergent',
#    'Additional',
#    'Details',
#    'Style',
#    'Code',
#    'W109',
#    'In',
#    'the',
#    'Box',
#    '1',
#    'Sweater',
#    '.'],
#   ['Kuhuk',
#    'Plastic',
#    'Bangle',
#    'Set',
#    '(',
#    'Pack',
#    'of',
#    '17',
#    ')',
#    'Price',
#    '',
#    '.',
#    '',
#    '495',
#    'Hand',
#    'Made',
#    'Jewellery',
#    'Hand',
#    'Made',
#    'Jewellery',
#    '.'],
#   ['Kuhuk',
#    'Plastic',
#    'Bangle',
#    'Set',
#    '(',
#    'Pack',
#    'of',
#    '31',
#    ')',
#    'Price',
#    '',
#    '.',
#    '',
#    '440',
#    'Hand',
#    'Made',
#    'Jewellery',
#    'Hand',
#    'Made',
#    'Jewellery',
#    '.'],
#   ['Kuhuk',
#    'Plastic',
#    'Bangle',
#    'Set',
#    '(',
#    'Pack',
#    'of',
#    '17',
#    ')',
#    'Price',
#    '',
#    '.',
#    '',
#    '495',
#    'Hand',
#    'Made',
#    'Jewellery',
#    'Hand',
#    'Made',
#    'Jewellery',
#    '.'],
#   ['Kuhuk',
#    'Plastic',
#    'Bangle',
#    'Set',
#    '(',
#    'Pack',
#    'of',
#    '17',
#    ')',
#    'Price',
#    '',
#    '.',
#    '',
#    '495',
#    'Hand',
#    'Made',
#    'Jewellery',
#    'Hand',
#    'Made',
#    'Jewellery',
#    '.'],
#   ['Key',
#    'Features',
#    'of',
#    'Airwind',
#    'Xylophone001',
#    'Min',
#    'Age',
#    '',
#    '.',
#    '',
#    'Musical',
#    'Instruments',
#    '',
#    'Specifications',
#    'of',
#    'Airwind',
#    'Xylophone001',
#    '(',
#    'Multicolor',
#    ')',
#    'Product',
#    'Dimensions',
#    'Product',
#    'Weight',
#    '325',
#    'g',
#    'Product',
#    'Depth',
#    '5',
#    'cm',
#    'Product',
#    'Width',
#    '14',
#    'cm',
#    'Product',
#    'Height',
#    '20',
#    'cm',
#    'Important',
#    'Note',
#    'The',
#    'color',
#    'of',
#    'some',
#    'product',
#    'parts',
#    'may',
#    'vary',
#    'from',
#    'what',
#    'is',
#    'shown',
#    'in',
#    'the',
#    'image',
#    'General',
#    'Age',
#    'Group',
#    '1',
#    '-',
#    '5',
#    'Years',
#    'Ideal',
#    'for',
#    'Boys',
#    '',
#    'Girls',
#    'Type',
#    'Musical',
#    'Instruments',
#    'Material',
#    'Wood',
#    'Character',
#    'Xylophone',
#    'In',
#    'the',
#    'Box',
#    '1',
#    'xylophone',
#    '.'],
#   ['Jewels5',
#    'Davita',
#    'Yellow',
#    'Gold',
#    'Diamond',
#    '18',
#    'K',
#    'Ring',
#    'Price',
#    '',
#    '.',
#    '',
#    '25213',
#    'Diamond',
#    'Jewellery',
#    'At',
#    'Lowest',
#    'Price',
#    'Diamond',
#    'Jewellery',
#    'At',
#    'Lowest',
#    'Price',
#    '.'],
#   ['Karatcraft',
#    'Triniya',
#    'Promise',
#    'Gold',
#    'Diamond',
#    '18',
#    'K',
#    'Ring',
#    'Price',
#    '',
#    '.',
#    '',
#    '34661',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
#    'marvel',
#    'For',
#    'the',
#    'connoisseur',
#    'like',
#    'you',
#    'this',
#    'is',
#    'a',
#    'perfect',
#    'piece',
#    'of',
#    'Diamond',
#    'Jewellery',
#    'to',
#    'flaunt',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
#    'marvel',
#    'For',
#    'the',
#    'connoisseur',
#    'like',
#    'you',
#    'this',
#    'is',
#    'a',
#    'perfect',
#    'piece',
#    'of',
#    'Diamond',
#    'Jewellery',
#    'to',
#    'flaunt',
#    '.'],
#   ['Jewels5',
#    'Jaidon',
#    'Yellow',
#    'Gold',
#    'Diamond',
#    '18',
#    'K',
#    'Ring',
#    'Price',
#    '',
#    '.',
#    '',
#    '25399',
#    'Diamond',
#    'Jewellery',
#    'At',
#    'Lowest',
#    'Price',
#    'Diamond',
#    'Jewellery',
#    'At',
#    'Lowest',
#    'Price',
#    '.'],
#   ['Jewels5',
#    'Ganesha',
#    'Gold',
#    'Diamond',
#    'Rhodium',
#    '14',
#    'K',
#    'Ring',
#    'Price',
#    '',
#    '.',
#    '',
#    '36341',
#    'Diamond',
#    'Jewellery',
#    'At',
#    'Lowest',
#    'Price',
#    'Diamond',
#    'Jewellery',
#    'At',
#    'Lowest',
#    'Price',
#    '.'],
#   ['Jewels5',
#    'Karasel',
#    'Yellow',
#    'Gold',
#    'Diamond',
#    '18',
#    'K',
#    'Ring',
#    'Price',
#    '',
#    '.',
#    '',
#    '31720',
#    'Diamond',
#    'Jewellery',
#    'At',
#    'Lowest',
#    'Price',
#    'Diamond',
#    'Jewellery',
#    'At',
#    'Lowest',
#    'Price',
#    '.'],
#   ['Jewels5',
#    'Jaelyn',
#    'Yellow',
#    'Gold',
#    'Diamond',
#    '18',
#    'K',
#    'Ring',
#    'Price',
#    '',
#    '.',
#    '',
#    '34124',
#    'Diamond',
#    'Jewellery',
#    'At',
#    'Lowest',
#    'Price',
#    'Diamond',
#    'Jewellery',
#    'At',
#    'Lowest',
#    'Price',
#    '.'],
#   ['Karatcraft',
#    'Clariz',
#    'Gold',
#    'Diamond',
#    '18',
#    'K',
#    'Ring',
#    'Price',
#    '',
#    '.',
#    '',
#    '33106',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
#    'marvel',
#    'For',
#    'the',
#    'connoisseur',
#    'like',
#    'you',
#    'this',
#    'is',
#    'a',
#    'perfect',
#    'piece',
#    'of',
#    'Diamond',
#    'Jewellery',
#    'to',
#    'flaunt',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
#    'marvel',
#    'For',
#    'the',
#    'connoisseur',
#    'like',
#    'you',
#    'this',
#    'is',
#    'a',
#    'perfect',
#    'piece',
#    'of',
#    'Diamond',
#    'Jewellery',
#    'to',
#    'flaunt',
#    '.'],
#   ['Jewels5',
#    'Lavatera',
#    'Yellow',
#    'Gold',
#    'Diamond',
#    '18',
#    'K',
#    'Ring',
#    'Price',
#    '',
#    '.',
#    '',
#    '28172',
#    'Diamond',
#    'Jewellery',
#    'At',
#    'Lowest',
#    'Price',
#    'Diamond',
#    'Jewellery',
#    'At',
#    'Lowest',
#    'Price',
#    '.'],
#   ['Karatcraft',
#    'Twinoh',
#    'Gold',
#    'Diamond',
#    '18',
#    'K',
#    'Ring',
#    'Price',
#    '',
#    '.',
#    '',
#    '29850',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
#    'marvel',
#    'For',
#    'the',
#    'connoisseur',
#    'like',
#    'you',
#    'this',
#    'is',
#    'a',
#    'perfect',
#    'piece',
#    'of',
#    'Diamond',
#    'Jewellery',
#    'to',
#    'flaunt',
#    'Set',
#    'to',
#    'look',
#    'like',
#    'a',
#    'Solitaire',
#    'Diamond',
#    'ring',
#    '',
#    'Solitana',
#    'Ring',
#    'is',
#    'a',
#    'designer’s',
#    'marvel',
#    'For',
#    'the',
#    'connoisseur',
#    'like',
#    'you',
#    'this',
#    'is',
#    'a',
#    'perfect',
#    'piece',
#    'of',
#    'Diamond',
#    'Jewellery',
#    'to',
#    'flaunt',
#    '.'],
#   ['Jewels5',
#    'Makale',
#    'Yellow',
#    'Gold',
#    'Diamond',
#    '18',
#    'K',
#    'Ring',
#    'Price',
#    '',
#    '.',
#    '',
#    '30475',
#    'Diamond',
#    'Jewellery',
#    'At',
#    'Lowest',
#    'Price',
#    'Diamond',
#    'Jewellery',
#    'At',
#    'Lowest',
#    'Price',
#    '.'],
#   ['',
#    '899',
#    'MSL',
#    'Footwear',
#    'was',
#    'created',
#    'in',
#    '2009',
#    '',
#    'with',
#    'the',
#    'promise',
#    'of',
#    'offering',
#    'Every',
#    'Day',
#    'Low',
#    'Price',
#    'in',
#    'the',
#    'fashion',
#    'footwear',
#    'segment',
#    'Our',
#    'goal',
#    'is',
#    'to',
#    'provide',
#    'vide',
#    'range',
#    'of',
#    'products',
#    'to',
#    'customer',
#    'with',
#    'best',
#    'competitive',
#    'price',
#    '',
#    'Specifications',
#    'of',
#    'MSL',
#    'Trendy',
#    'Loafers',
#    'General',
#    'Ideal',
#    'For',
#    'Women',
#    'Occasion',
#    'Casual',
#    'Shoe',
#    'Details',
#    'Lining',
#    'Synthetic',
#    'Leather',
#    'Sole',
#    'Material',
#    'Tpr',
#    'Inner',
#    'Material',
#    'Synthetic',
#    'Leather',
#    'Heel',
#    'Height',
#    '0',
#    'inch',
#    'Outer',
#    'Material',
#    'Synthetic',
#    'Leather',
#    'Color',
#    '11',
#    '',
#    'Black',
#    'Additional',
#    'Details',
#    'Care',
#    'Instructions',
#    'Rotate',
#    'Your',
#    'Pair',
#    'Of',
#    'Shoes',
#    'Once',
#    'Every',
#    'Other',
#    'Day',
#    '',
#    'Allowing',
#    'Them',
#    'To',
#    'De',
#    '-',
#    'Odorize',
#    'And',
#    'Retain',
#    'Their',
#    'Shapes',
#    '.'],
#   ['Key',
#    'Features',
#    'of',
#    'AYESHA',
#    'Metal',
#    'Chain',
#    'Ideal',
#    'For',
#    '',
#    '.',
#    '',
#    'Gold',
#    '',
#    'Specifications',
#    'of',
#    'AYESHA',
#    'Metal',
#    'Chain',
#    'Silver',
#    'Features',
#    'Silver',
#    'Weight',
#    'NA',
#    'g',
#    'General',
#    'Brand',
#    'AYESHA',
#    'Precious/Artificial',
#    'Jewellery',
#    'Fashion',
#    'Jewellery',
#    'Model',
#    'Number',
#    'AY',
#    '-',
#    '8567',
#    'Type',
#    'Chain',
#    'Ideal',
#    'For',
#    'Women',
#    'Color',
#    'Gold',
#    'Diamond',
#    'Features',
#    'Diamond',
#    'Weight',
#    'NA',
#    'carat',
#    'Diamond',
#    'Shape',
#    'NA',
#    'Diamond',
#    'Color',
#    'Grade',
#    'NA',
#    'Diamond',
#    'Clarity',
#    'NA',
#    'Gold',
#    'Features',
#    'Gold',
#    'Purity',
#    'NA',
#    'K',
#    'Body',
#    '&',
#    'Design',
#    'Features',
#    'Base',
#    'Material',
#    'Metal',
#    'Gemstone',
#    'NA',
#    'Plating',
#    'NA',
#    'Additional',
#    'Features',
#    'Certification',
#    'NA',
#    'In',
#    'the',
#    'Box',
#    'Pack',
#    'of',
#    '1',
#    '.'],
#   ['Specifications',
#    'of',
#    'Pavvoin',
#    'Lingerie',
#    'Set',
#    'Lingerie',
#    'Set',
#    'Details',
#    'Inner',
#    'Lining',
#    'Nylon',
#    'Lining',
#    'Fabric',
#    'Nylon',
#    'Type',
#    'Bra',
#    '&',
#    'Panty',
#    'Set',
#    'General',
#    'Details',
#    'Age',
#    'Group',
#    'N',
#    'A',
#    '-',
#    'N',
#    'A',
#    'month',
#    'Pattern',
#    'Solid',
#    'Cup',
#    'Details',
#    'Cup',
#    'Size',
#    'B',
#    'Cup',
#    'Type',
#    'Molded',
#    'Padded',
#    'push',
#    '-',
#    'up',
#    'Cup',
#    'Fabric',
#    'Care',
#    'Gentle',
#    'Machine',
#    'Wash',
#    'in',
#    'Lukewarm',
#    'Water',
#    '',
#    'Do',
#    'Not',
#    'Bleach',
#    'Additional',
#    'Details',
#    'This',
#    'Product',
#    'Will',
#    'Fit',
#    'In',
#    'Your',
#    'Wardrobe',
#    '',
#    'This',
#    'Padded',
#    'Underwire',
#    'Lingerie',
#    'Set',
#    'Is',
#    'Good',
#    'Combination',
#    'Of',
#    'Comfort',
#    'And',
#    'Fashion',
#    'This',
#    'Is',
#    'The',
#    'Perfect',
#    'Lingerie',
#    'Set',
#    'Which',
#    'Womens',
#    'Wants',
#    'In',
#    'the',
#    'Box',
#    'Bra',
#    '',
#    'Panty',
#    '.'],
#   ['You2Deal',
#    'Wood',
#    '&',
#    'Iron',
#    'Handicraft',
#    'Antique',
#    'Style',
#    'Home',
#    'Decor',
#    'Cycle',
#    'Gift',
#    'Item',
#    'Showpiece',
#    '-',
#    '25',
#    'cm',
#    '(',
#    'Wooden',
#    '',
#    'Iron',
#    '',
#    'Black',
#    ')',
#    'Price',
#    '',
#    '.',
#    '',
#    '449',
#    'Wooden',
#    '&',
#    'Iron',
#    'Cycle',
#    'Antique',
#    'Home',
#    'Decor',
#    'Product',
#    'is',
#    'a',
#    'perfect',
#    'home',
#    'decor',
#    'product',
#    'Wooden',
#    '&',
#    'Iron',
#    'Cycle',
#    'is',
#    'made',
#    'from',
#    'high',
#    'quality',
#    'wood',
#    'and',
#    'iron',
#    'Can',
#    'be',
#    'give',
#    'as',
#    'gift',
#    'to',
#    'childrens',
#    'Wooden',
#    '&',
#    'Iron',
#    'Cycle',
#    'Antique',
#    'Home',
#    'Decor',
#    'Product',
#    'is',
#    'a',
#    'perfect',
#    'home',
#    'decor',
#    'product',
#    'Wooden',
#    '&',
#    'Iron',
#    'Cycle',
#    'is',
#    'made',
#    'from',
#    'high',
#    'quality',
#    'wood',
#    'and',
#    'iron',
#    'Can',
#    'be',
#    'give',
#    'as',
#    'gift',
#    'to',
#    'childrens',
#    '',
#    '.'],
#   ['Key',
#    'Features',
#    'of',
#    'JewelFox',
#    'Gold',
#    'Tanmaniya',
#    'Certification',
#    '',
#    '.',
#    '',
#    'SGL',
#    '',
#    'Specifications',
#    'of',
#    'JewelFox',
#    'Gold',
#    'Tanmaniya',
#    'Pearl',
#    'Features',
#    'Pearl',
#    'Type',
#    'NA',
#    'General',
#    'Base',
#    'Material',
#    'Gold',
#    'Brand',
#    'JewelFox',
#    'Model',
#    'Number',
#    'VJTN',
#    '1786',
#    'Precious/Artificial',
#    'Jewellery',
#    'Precious',
#    'Jewellery',
#    'Plating',
#    'NA',
#    'Type',
#    'Tanmaniya',
#    'Color',
#    'Yellow',
#    'Silver',
#    'Features',
#    'Silver',
#    'Weight',
#    '0',
#    'g',
#    'Chain',
#    'Features',
#    'Chain',
#    'Included',
#    'No',
#    'Diamond',
#    'Features',
#    'Diamond',
#    'Weight',
#    '0',
#    '20900000000000002',
#    'carat',
#    'Diamond',
#    'Shape',
#    'Round',
#    'Design',
#    '&',
#    'Features',
#    'Gemstone',
#    'Diamond',
#    'In',
#    'the',
#    'Box',
#    'Sales',
#    'Package',
#    '1',
#    'Tanmaniya',
#    'Additional',
#    'Features',
#    'Certification',
#    'SGL',
#    '.'],
#   ['Key',
#    'Features',
#    'of',
#    'JewelFox',
#    'Gold',
#    'Tanmaniya',
#    'Certification',
#    '',
#    '.',
#    '',
#    'SGL',
#    '',
#    'Specifications',
#    'of',
#    'JewelFox',
#    'Gold',
#    'Tanmaniya',
#    'Pearl',
#    'Features',
#    'Pearl',
#    'Type',
#    'NA',
#    'General',
#    'Base',
#    'Material',
#    'Gold',
#    'Brand',
#    'JewelFox',
#    'Model',
#    'Number',
#    'VJTN',
#    '1782',
#    'Precious/Artificial',
#    'Jewellery',
#    'Precious',
#    'Jewellery',
#    'Plating',
#    'NA',
#    'Type',
#    'Tanmaniya',
#    'Color',
#    'Yellow',
#    'Silver',
#    'Features',
#    'Silver',
#    'Weight',
#    '0',
#    'g',
#    'Chain',
#    'Features',
#    'Chain',
#    'Included',
#    'No',
#    'Diamond',
#    'Features',
#    'Diamond',
#    'Weight',
#    '0',
#    '29400000000000004',
#    'carat',
#    'Diamond',
#    'Shape',
#    'Round',
#    'Design',
#    '&',
#    'Features',
#    'Gemstone',
#    'Diamond',
#    'In',
#    'the',
#    'Box',
#    'Sales',
#    'Package',
#    '1',
#    'Tanmaniya',
#    'Additional',
#    'Features',
#    'Certification',
#    'SGL',
#    '.']]}

# %%
# %cd /content/drive/MyDrive/Describing_a_Knowledge_Base/
# !python main.py --cuda --mode 1 --type 1
# Out:
# /content/drive/MyDrive/Describing_a_Knowledge_Base
# Finish build vocabulary
# Finish build word dictionary
# number of training examples: 3943
# model restored
# Read test data
# Type index from (0 to 875) to continue:
# 1
# Table:
# <Name_ID> : Sorcerer (horse) <instance of> : Thoroughbred <child> : Maid of Orleans (horse) <child> : Morel (horse) <child> : Smolensko (horse) <child> : Soothsayer (horse) <child> : Sorcery (horse) <child> : Wizard (horse) <child> : Trophonius (horse) <date of birth> : 1796
#
# Refer:
# Sorcerer (horse) ( 1796 – 1821 ) was a British Thoroughbred racehorse . sorcerer 's son Smolensko (horse) . amongst his progeny were Morel (horse) Maid of Orleans (horse) Wizard (horse) Soothsayer (horse) Sorcery (horse) Trophonius (horse) Comus and Smolensko (horse) . sorcerer was a black colt bred by Sir Charles Bunbury and foaled in 1796 .
#
# /content/drive/MyDrive/Describing_a_Knowledge_Base/structure_generator/DecoderRNN.py:75: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/LegacyDefinitions.cpp:28.)
#   attn_scores.data.masked_fill_(enc_mask.data.byte(), -10000.0)
# 100
# Result:
# Sorcerer (horse) ( 1796 – 1796 ) was an undefeated British Thoroughbred racehorse and sire . he was sired by the great winner of the 20th Century . he was sired by the great winner of the 20th Century . he was sired by the great winner of the 20th Century . he was sired by the great winner of the 20th Century . he was sired by the great winner of the 20th Century . he was sired by the great winner of the 20th Century . he was sired by the great winner of the 20th Century . he
# ------------------------------------------------------------------------------------------------------------------------
# Type index from (0 to 875) to continue:
# 2
# Table:
# <Name_ID> : Round Table (horse) <child> : Baldric (horse) <child> : He's A Smoothie <child> : King's Bishop <child> : Apalachee (horse) <child> : Artaius (horse) <child> : Flirting Around <date of birth> : 1954
#
# Refer:
# Round Table (horse) ( April 6 1954 – June 13 1987 ) was an American Thoroughbred Hall of Fame racehorse . he sired 83 stakes winners including He's A Smoothie Baldric (horse) Apalachee (horse) Artaius (horse) Cellini Advocator Flirting Around King's Bishop and Poker who was the damsire of two Hall of Fame inductees Seattle Slew and Silver Charm . round Table was foaled at Claiborne Farm in Kentucky on the night of April 6 1954 .
#
# 56
# Result:
# Round Table (horse) ( 1954 – 1954 ) was an American-bred Thoroughbred racehorse and sire . he was sired by the Round Table (horse) and sire . he was sired by the great winner of the Year in the Year and sire . he was sired by the great winner of the Year in the Year and sire .
# ------------------------------------------------------------------------------------------------------------------------
# Type index from (0 to 875) to continue:
# 3
# Table:
# <Name_ID> : Selim (horse) <instance of> : Thoroughbred <date of birth> : 1802 <child> : Sultan (horse) <child> : Azor (horse) <child> : Filly by Selim <child> : Medora (horse) <child> : Turquoise (horse)
#
# Refer:
# Selim (horse) ( 1802 – 1825 ) was a British Thoroughbred racehorse . his progeny included Azor (horse) Medora (horse) Sultan (horse) and Turquoise (horse) . his progeny included Epsom Derby winner Azor (horse) Epsom Oaks winners Medora (horse) and Turquoise (horse) 2000 Guineas winners Nicolo and Turcoman and an Filly by Selim that won the 1000 Guineas . selim also sired six-time Champion sire Sultan (horse) . selim was a chestnut colt bred by General Sparrow and foaled in 1802 .
#
# 100
# Result:
# Selim (horse) ( 1802 – 1802 ) was an undefeated Thoroughbred racehorse and sire . he was sired by the great winner of the 20th Century . he was sired by the great winner of the 20th Century . he was sired by the great winner of the 20th Century . he was sired by the great winner of the 20th Century . he was sired by the great winner of the 20th Century . he was sired by the great winner of the 20th Century . he was sired by the great winner of the 20th Century . he was
# ------------------------------------------------------------------------------------------------------------------------
# Type index from (0 to 875) to continue:
# 4
# Table:
# <Name_ID> : Rubens (horse) <instance of> : Thoroughbred <date of birth> : 1805 <child> : Landscape (horse) <child> : Pastille (horse) <child> : Rubens mare <child> : Whizgig
#
# Refer:
# Rubens (horse) ( 1805 – February 1829 ) was a British Thoroughbred racehorse . his progeny included Landscape (horse) Pastille (horse) and Whizgig . his progeny included Epsom Oaks winners Landscape (horse) and Pastille (horse) and 1000 Guineas winner Whizgig . his unnamed daughter the 1819 Rubens mare was the dam of Phosphorus and two other classic winners . rubens was a chestnut colt bred by the Prince of Wales and foaled in 1805 .
#
# 100
# Result:
# Rubens (horse) ( 1805 – 1805 ) was an American Thoroughbred racehorse and sire . he was sired by the great winner of the 20th Century . he was sired by the great winner of the 20th Century . he was sired by the great winner of the 20th Century . he was sired by the great winner of the 20th Century . he was sired by the great winner of the 20th Century . he was sired by the great winner of the 20th Century . he was sired by the great winner of the 20th Century . he was
# ------------------------------------------------------------------------------------------------------------------------
# Type index from (0 to 875) to continue:
# 5
# Table:
# <Name_ID> : Theatrical (horse) <instance of> : Thoroughbred <father> : Nureyev (horse) <child> : Royal Anthem (horse) <child> : Media Puzzle <child> : Zagreb (horse) <date of birth> : 1982
#
# Refer:
# Theatrical (horse) ( 13 March 1982 – 31 August 2012 ) was an Irish-bred Thoroughbred racehorse who won the 1987 Breeders' Cup Turf and was a successful sire . he was sired by Nureyev (horse) the disqualified " winner " of the 1980 2000 Guineas . among his progeny Theatrical sired Media Puzzle the 2002 Melbourne Cup winner Zagreb (horse) ( Irish Derby ) and Royal Anthem (horse) whose wins include the Canadian International Stakes ( 1998 ) and the International Stakes ( 1999 ) .
#
# 100
# Result:
# Theatrical (horse) ( 1982 – 1982 ) was an American Thoroughbred racehorse and sire . he was sired by the great winner of the 20th Century . he was sired by the great winner of the 20th Century . he was sired by the great winner of the 20th Century . he was sired by the great winner of the 20th Century . he was sired by the great winner of the mare winner Nureyev (horse) in the United States . he was sired by the great winner of the mare winner Nureyev (horse) in the United States . he was sired by
# ------------------------------------------------------------------------------------------------------------------------
# Type index from (0 to 875) to continue:
# 6
# Table:
# <Name_ID> : Three Bars <child> : Lena's Bar <child> : Rocket Bar <child> : Sugar Bars <child> : Zippo Pat Bars <child> : Lightning Bar <date of birth> : 1940
#
# Refer:
# his offspring Rocket Bar Sugar Bars Lena's Bar Lightning Bar and Zippo Pat Bars were all inducted into the American Quarter Horse Hall of Fame . foaled April 8 1940 Three Bars was sired by Percentage and out of Myrtle Dee .
#
# 100
# Result:
# Three Bars ( 1940 – 1940 ) was an undefeated Thoroughbred racehorse and sire . he was sired by the Derby winner of his racing career and his racing career and his racing career and his racing career and his racing career and his racing career and his racing career and his racing career and his racing career and his racing career and his racing career and his racing career and his racing career and his racing career and his racing career and his racing career and his racing career and his racing career and his racing career and his racing
# ------------------------------------------------------------------------------------------------------------------------
# Type index from (0 to 875) to continue:
# 7
# Table:
# <Name_ID> : Ragusa (horse) <instance of> : Thoroughbred <father> : Ribot (horse) <child> : Morston (horse) <child> : Ragstone (horse) <date of birth> : 1960
#
# Refer:
# Ragusa (horse) ( foaled 1960 ) was an Irish Thoroughbred racehorse . he was sired by Ribot (horse) who was standing in Italy when Guggenheim sent his mare Fantan to be covered in 1959 . the best of his progeny included Morston (horse) Ragstone (horse) Caliban ( Coronation Cup ) and Homeric .
#
# 33
# Result:
# Ragusa (horse) ( 1960 – 1960 ) was a British Thoroughbred racehorse and sire . he was sired by the great winner of the undefeated of the mare of the mare winner .
# ------------------------------------------------------------------------------------------------------------------------
# Type index from (0 to 875) to continue:
# 8
# Table:
# <Name_ID> : Regulus (horse) <instance of> : Thoroughbred <father> : Godolphin Arabian <child> : Alipes (horse) <child> : Spilletta <date of birth> : 1739
#
# Refer:
# Regulus (horse) was an undefeated Thoroughbred racehorse stallion foaled in 1739 . regulus was by the Godolphin Arabian his dam the noted Grey Robinson by Bald Galloway and out of Sister To Old Country Wench ( dam of Squirt ) by Snake out of Old Grey Wilkes a daughter of Old Hautboy . 1750 ) Fearnought ( 1755 ) ( exported to the US ) Alipes (horse) Star Cato Juba Ascha Grisewood 's Lady Thigh Miss Belsea and many important broodmares including Spilletta ( dam of Eclipse ) .
#
# 15
# Result:
# Regulus (horse) ( 1739 – 1739 ) was an American Thoroughbred racehorse and sire .
# ------------------------------------------------------------------------------------------------------------------------
# Type index from (0 to 875) to continue:
# 9
# Table:
# <Name_ID> : Rock of Gibraltar (horse) <father> : Danehill (horse) <child> : Eagle Mountain (horse) <child> : Society Rock <child> : Mount Nelson (horse) <date of birth> : 1999
#
# Refer:
# Rock of Gibraltar (horse) ( foaled 8 March 1999 in Ireland ) is a Champion racehorse and stallion owned by Coolmore . his best sons include Hong Kong Cup winner and Epsom Derby runner-up Eagle Mountain (horse) as well as Group One winners Samitar Seventh Rock Mount Nelson (horse) Varenar and Society Rock . this also means that Rock of Gibraltar is inbred to Nearctic and Natalma 4 x 4 however like all of Danehill (horse) 's offspring Rock of Gibraltar is inbred 4 x 4 to the mare Natalma .
#
# 27
# Result:
# Rock of Gibraltar (horse) ( 1999 – 1999 ) was an American Thoroughbred racehorse and sire . he was sired by the great winner of the 20th Century .
# ------------------------------------------------------------------------------------------------------------------------
# Type index from (0 to 875) to continue:
# 10
# Table:
# <Name_ID> : Selkirk (horse) <instance of> : Thoroughbred <father> : Sharpen Up <child> : Wince <child> : Kastoria (horse) <date of birth> : 1988
#
# Refer:
# Selkirk (horse) ( February 19 1988 – January 3 2013 ) was an American-bred Thoroughbred race horse and sire who raced mainly in Europe . he was sired by Sharpen Up a British racehorse who won the Middle Park Stakes in 1971 before becoming a successful breeding stallion . his most successful offspring included Classic winners Wince and Kastoria (horse) as well as Dubai Duty Free winner Cityscape the Pretty Polly Stakes winner Thistle Bird and the Champion Hurdle
#
# 13
# Result:
# Selkirk (horse) ( 1988 – 1988 ) was an American Thoroughbred racehorse .
# ------------------------------------------------------------------------------------------------------------------------
# Type index from (0 to 875) to continue:
#
# Traceback (most recent call last):
#   File "main.py", line 163, in <module>
#     i = int(seq_str)
# ValueError: invalid literal for int() with base 10: ''
